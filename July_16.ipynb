# %%
from langchain.embeddings.openai import OpenAIEmbeddings
# from langchain.vectorstores import Pinecone
# from langchain.llms import OpenAI

from openai import OpenAI
import json
import re

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
with open('description.txt', 'r') as file:
    text = file.read()


# First, let's clean and parse the JSON data properly
def clean_json_data(text):
    """Clean the JSON string and parse it properly"""
    # Remove unicode characters like \u00a0
    cleaned_text = re.sub(r'\\u00a0', '', text)
    # Parse the JSON
    data = json.loads(cleaned_text)
    return data

# Clean the data
products = clean_json_data(text)
print(f"Found {len(products)} products")
print(f"First product model: {products[0]['model_no']}")

def parse_description(desc):
    # Extract short and full descriptions separately
    full_desc_match = re.search(r"Full Description:\s*(.*?)(?:\.|$)", desc)
    short_desc_match = re.search(r"Short Description:\s*(.*?)(?:\.|$)", desc)
    
    # Extract all other key-value style entries
    key_value_pairs = re.findall(r"([\w\s/]+?):\s*(.*?)(?:\.|$)", desc)

    parsed = {
        "full_description": full_desc_match.group(1) if full_desc_match else "",
        # "short_description": short_desc_match.group(1) if short_desc_match else "",
        "specs": {k.strip(): v.strip() for k, v in key_value_pairs 
                  if k not in ["Full Description", "Short Description"]}
    }
    return parsed

# Apply parsing
for item in products:
    parsed = parse_description(item["description"])
    item["full_description"] = parsed["full_description"]
    # item["short_description"] = parsed["short_description"]
    item["specs"] = parsed["specs"]
    del item["description"]
    specs = item.get("specs", {})
    if "Fi" in specs:
        # Move value to correct key
        specs["Wi-Fi"] = specs.pop("Fi")

def clean_spec_value(key, value):
    value = value.strip()
    
    # Normalize "No XYZ support" → "not supported"
    if re.match(r'no\s+[a-zA-Z0-9\-/ ]+\s+support', value, flags=re.IGNORECASE):
        return "not supported"
    
    # Normalize "XYZ not available" → "not available"
    if re.search(r'not available', value, flags=re.IGNORECASE):
        return "not available"

    return value

def specs_to_string(specs):
    parts = []
    for k, v in specs.items():
        cleaned = clean_spec_value(k, v)
        parts.append(f"{k}: {cleaned}")
    return ". ".join(parts)

def create_embedding_text(item):
    parts = [
        f"Model No: {item['model_no']}",
        # f"Short Description: {item['short_description']}",
        f"Full Description: {item['full_description']}",
        specs_to_string(item["specs"])  # Cleaned specs as one string
    ]
    return ". ".join(parts)

def normalize_text(text):
    text = text.lower()
    text = re.sub(r'\s+', ' ', text)              # Collapse multiple spaces
    text = re.sub(r'\s([:;,.])', r'\1', text)      # Remove space before punctuation
    text = text.strip()
    return text

# Add new field for embedding
for item in products:
    item["embedding_text"] = create_embedding_text(item)
    item["embedding_text"] = item["embedding_text"].lower()
    item["embedding_text"] = normalize_text(item["embedding_text"])


docs = [item["embedding_text"] for item in products]

import os
from openai import OpenAI
from pinecone import Pinecone, ServerlessSpec

# Set your keys
os.environ["OPENAI_API_KEY"] = "YOUR_OPENAI_API_KEY_HERE"   # OpenAI key
os.environ["PINECONE_API_KEY"] = "YOUR_PINECONE_API_KEY_HERE"
# Out:
# Found 100 products
# First product model: I-7547

# %%
embeddings=OpenAIEmbeddings(api_key=os.environ['OPENAI_API_KEY'])
embeddings
# Out:
# /var/folders/3c/zyyqm72564xf1ztp8l6yb8xm0000gn/T/ipykernel_15697/3098385080.py:1: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings=OpenAIEmbeddings(api_key=os.environ['OPENAI_API_KEY'])
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x1192846a0>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x11a6ecbb0>, model='text-embedding-ada-002', deployment='text-embedding-ada-002', openai_api_version='', openai_api_base=None, openai_api_type='', openai_proxy='', embedding_ctx_length=8191, openai_api_key='YOUR_OPENAI_API_KEY_HERE', openai_organization=None, allowed_special=set(), disallowed_special='all', chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None)

# %%
# 1. Initialize clients
client = OpenAI(api_key="YOUR_OPENAI_API_KEY_HERE")

pc = Pinecone(api_key="YOUR_PINECONE_API_KEY_HERE", environment="us-east-1")

# %%
from pinecone import Pinecone, ServerlessSpec
from openai import OpenAI
import re


index_name = "model-prompter"
if index_name not in pc.list_indexes().names():
    pc.create_index(
        name= index_name,
        dimension=3072,
        metric="cosine",
        spec=ServerlessSpec(cloud="aws", region="us-east-1")
    )

index = pc.Index("model-prompter")

def extract_model_id(text):
    match = re.search(r"model no:\s*([a-zA-Z0-9\-_.]+)", text, re.IGNORECASE)
    return match.group(1) if match else None

# Embed and upsert
records = []
for doc in docs:
    model_id = extract_model_id(doc)
    if model_id:
        response = client.embeddings.create(
            model="text-embedding-3-large",
            input=[doc]
        )
        embedding = response.data[0].embedding
        records.append({
            "id": model_id,
            "values": embedding,
            "metadata": {"text": doc}
        })

index.upsert(vectors=records)
# Out:
# {'upserted_count': 100}

# %%
query_text = "USB to RS232 converter"

# Embed the query
query_embedding = client.embeddings.create(
    model="text-embedding-3-large",
    input=[query_text]
).data[0].embedding

# Query Pinecone
results = index.query(
    vector=query_embedding,
    top_k=5,
    include_metadata=True
)

# Display results
for match in results['matches']:
    print(f"✅ ID: {match['id']}\n🔹 Score: {match['score']:.4f}\n📝 Text: {match['metadata']['text'][:150]}\n---")
# Out:
# ✅ ID: usb232.
# 🔹 Score: 0.6565
# 📝 Text: model no: usb232. full description: rs232 to usb onverter. short description: rs232 converter. serial port: supports rs232 serial port. ethernet: not
# ---
# ✅ ID: usb
# 🔹 Score: 0.6168
# 📝 Text: model no: usb 2514. full description: usb to 4-port rs-232 converter. short description: usb to rs232 converter. serial port: supports rs232 serial po
# ---
# ✅ ID: usb485.
# 🔹 Score: 0.5920
# 📝 Text: model no: usb485. full description: rs485 to usb onverter. short description: rs485 converter. serial port: supports rs485 serial port. ethernet: not
# ---
# ✅ ID: i-7561u.
# 🔹 Score: 0.5899
# 📝 Text: model no: i-7561u. full description: high-speed usb to isolated rs-232/422/485 converter with ca-usb18 cable. short description: usb to serial convert
# ---
# ✅ ID: i-7520a.
# 🔹 Score: 0.5217
# 📝 Text: model no: i-7520a. full description: isolated rs-232 to rs-422/485 converter. short description: serial converter. serial port: supports rs232, 422, a
# ---

# %%
# Out:
# Name: pinecone
# Version: 7.3.0
# Summary: Pinecone client and SDK
# Home-page: https://www.pinecone.io
# Author: Pinecone Systems, Inc.
# Author-email: support@pinecone.io
# License: Apache-2.0
# Location: /Users/akshayeiyer/Documents/My Projects/Langchain/VectorDB Pinecone project/venv/lib/python3.10/site-packages
# Requires: certifi, pinecone-plugin-assistant, pinecone-plugin-interface, python-dateutil, typing-extensions, urllib3
# Required-by:

# %%
import serpapi

results = serpapi.search({
    "q": "analog and digital i/o to modbus rtu",
    "location": "Austin, Texas, United States", 
    "hl": "en",
    "gl": "us",
    "engine": "google",
    "api_key": "0405f5209eae5d423ed1543842c123c70f1d3ee6341c6a557e644f500e7d3eac"
})

print(results)
# Out:
# {
#     "search_metadata": {
#         "id": "6879ed6c018c48d204358bb1",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/0056cf78c405db8f/6879ed6c018c48d204358bb1.json",
#         "pixel_position_endpoint": "https://serpapi.com/searches/0056cf78c405db8f/6879ed6c018c48d204358bb1.json_with_pixel_position",
#         "created_at": "2025-07-18 06:45:00 UTC",
#         "processed_at": "2025-07-18 06:45:26 UTC",
#         "google_url": "https://www.google.com/search?q=analog+and+digital+i%2Fo+to+modbus+rtu&oq=analog+and+digital+i%2Fo+to+modbus+rtu&uule=w+CAIQICIaQXVzdGluLFRleGFzLFVuaXRlZCBTdGF0ZXM&hl=en&gl=us&sourceid=chrome&ie=UTF-8",
#         "raw_html_file": "https://serpapi.com/searches/0056cf78c405db8f/6879ed6c018c48d204358bb1.html",
#         "total_time_taken": 2.36
#     },
#     "search_parameters": {
#         "engine": "google",
#         "q": "analog and digital i/o to modbus rtu",
#         "location_requested": "Austin, Texas, United States",
#         "location_used": "Austin,Texas,United States",
#         "google_domain": "google.com",
#         "hl": "en",
#         "gl": "us",
#         "device": "desktop"
#     },
#     "search_information": {
#         "query_displayed": "analog and digital i/o to modbus rtu",
#         "total_results": 845000,
#         "time_taken_displayed": 0.27,
#         "organic_results_state": "Results for exact spelling"
#     },
#     "inline_videos": [
#         {
#             "position": 1,
#             "title": "Read Analog Inputs of Extension IO Module over MODBUS ...",
#             "link": "https://www.youtube.com/watch?v=WyV-iPeT4Ng",
#             "thumbnail": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/af5c76b4610b644c913e0766ec61897b39f2d592d77204de2e7007dd013b3291.jpeg",
#             "channel": "PLC Programming Tutorials Tips and Tricks",
#             "duration": "8:46",
#             "platform": "YouTube"
#         },
#         {
#             "position": 2,
#             "title": "EBYTE Modbus RTU I/O Module Overview",
#             "link": "https://www.youtube.com/watch?v=hHMhLZqJmcQ",
#             "thumbnail": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/af5c76b4610b644c86bb8277f6aa156be9e69405dc3f1da7b0357fc344b3f284.jpeg",
#             "channel": "OnosTech",
#             "duration": "5:43",
#             "platform": "YouTube"
#         },
#         {
#             "position": 3,
#             "title": "How to Connect an HMI+PLC with a Remote I/O via Modbus",
#             "link": "https://www.youtube.com/watch?v=qHYuwHfaCM8",
#             "thumbnail": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/af5c76b4610b644cd3a3906782fafc325f00a29d30024a9a913fe7f6a79e8176.jpeg",
#             "channel": "Maple Systems, Inc.",
#             "duration": "16:09",
#             "platform": "YouTube"
#         }
#     ],
#     "immersive_products": [
#         {
#             "category": "Popular products",
#             "thumbnail": "https://encrypted-tbn1.gstatic.com/shopping?q=tbn:ANd9GcTkw3pMWrHqfFsliYnfBAI8wbTYAXQ-uXdxEYDrX8B5KGSgrHXzoWYvAr_-llSScSctcXsaSn_JG6EB8Z0si2rX2pDSXqJvc6rnD3sE-38e",
#             "source_logo": "https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn%3AANd9GcQpgfL0avcSnIIA7Wnlomi5kymZiO0A2kINnMkGZ3G1FlJRmOOARrbdPOOdSZARVbApsdeCP7QiIe5WxnPSOaIbtM4r",
#             "source": "Amazon",
#             "title": "4Di/4Do/2Ai/2Ao Digital Input and Output Analog Input and Output Module",
#             "price": "$108.53",
#             "extracted_price": 108.53,
#             "immersive_product_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...%3D",
#             "product_id": "9639918465576089577",
#             "serpapi_product_api": "https://serpapi.com/search.json?engine=google_product&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&product_id=9639918465576089577"
#         },
#         {
#             "category": "Popular products",
#             "thumbnail": "https://encrypted-tbn3.gstatic.com/shopping?q=tbn:ANd9GcRR_iNI9u9RCADqPWqmSHwekVhZWGhrmK_yvtTRHgYdnbJA03UQowf3sNq6Vwi_XxB8qS6GZ4-37ENkqb3NnIbpf-BVn2SuGyo8NSbKfKcZgq0mR2qgC1Q2",
#             "source_logo": "https://encrypted-tbn2.gstatic.com/favicon-tbn?q=tbn%3AANd9GcT0TsMMuS8IRIUU_Envbo02npaZ6DJgbXTwa-h2DSMswBydNyxi_1NukUkPuQPc8-6EH8dopTDEyU5ccMeLEvcSrbCBtAW3",
#             "source": "Amazon.com - Seller",
#             "title": "Taidacent PLC Analog I/O Input to RS485 Modbus RTU TCP Converter Module",
#             "price": "$29.58",
#             "extracted_price": 29.58,
#             "immersive_product_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...%3D",
#             "product_id": "2299146975835806284",
#             "serpapi_product_api": "https://serpapi.com/search.json?engine=google_product&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&product_id=2299146975835806284"
#         },
#         {
#             "category": "Popular products",
#             "thumbnail": "https://encrypted-tbn2.gstatic.com/shopping?q=tbn:ANd9GcQ8c-o1HttaBdYYFl39yqJ5NqOIDVqOs-Rd0ZWdnOQs9Ca-dBlKWdGjabTf5CYEPRM_VII4qfLz4otWyvBDA8lxR1IqI7-paprQZ3W7OgccO-8w510hNuLt",
#             "source_logo": "https://encrypted-tbn0.gstatic.com/favicon-tbn?q=tbn%3AANd9GcRFVTy9QZt3kDLYr9MJ9HjiFK9XN6q3lhZCIuaSy0bY5HQWmcYvaJVKxtb77a2pOLmf272nBFk4QFmzQbSPzwV1yOZC7m5T",
#             "source": "ComWinTop",
#             "title": "CWT-BK-04040202 4Di/4Do/2Ai/2Ao Digital input and output Analog Input and Output Rs485 Modbus Rtu Io Module",
#             "price": "$49.60",
#             "extracted_price": 49.6,
#             "immersive_product_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...",
#             "product_id": "5754668381181052102",
#             "serpapi_product_api": "https://serpapi.com/search.json?engine=google_product&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&product_id=5754668381181052102"
#         },
#         {
#             "category": "Popular products",
#             "thumbnail": "https://encrypted-tbn1.gstatic.com/shopping?q=tbn:ANd9GcTrvxyyUAz7_BcpxFBZYCYGswKRVlYarl7vTbxyr_GwXbLahZc3vmzPquMJ1Eh7nmzz4mMcT5jao7_SrAXu7MLAAArZ7OeC5LFxNo74eZwBxmpZcDmfhWiQ",
#             "source_logo": "https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn%3AANd9GcQpgfL0avcSnIIA7Wnlomi5kymZiO0A2kINnMkGZ3G1FlJRmOOARrbdPOOdSZARVbApsdeCP7QiIe5WxnPSOaIbtM4r",
#             "source": "Amazon",
#             "title": "4AI-4DI-4DO 12CH 12V 24V RS485 Analog Digital i Module",
#             "price": "$11.39",
#             "extracted_price": 11.39,
#             "immersive_product_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...",
#             "product_id": "5391029765941883724",
#             "serpapi_product_api": "https://serpapi.com/search.json?engine=google_product&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&product_id=5391029765941883724"
#         },
#         {
#             "category": "Popular products",
#             "thumbnail": "https://encrypted-tbn1.gstatic.com/shopping?q=tbn:ANd9GcTMoRoD3lNJCDDZHwhi5QMn85wNmbLmIGEJOTd3grTRON-09GdJcaB7JQMKEZfNJz11FYxR4ECuvLySPZTBA1kWKPPWfa1FD7aFPKE4Z3oM",
#             "source_logo": "https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn%3AANd9GcTlmZqkupJBUubloxCxqoRmLS_dWespgJwSgUhIJVlYQj6Cu_u4Tx7V6lktCFa4fSryvR4uvtZ5flfcfblXFdyZm_dvqYa77-4",
#             "source": "VP Process.Inc.",
#             "title": "VPE-4130 Modbus RTU Universal I/O Module",
#             "price": "$99.95",
#             "extracted_price": 99.95,
#             "immersive_product_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...%3D",
#             "product_id": "5687417807099585901",
#             "serpapi_product_api": "https://serpapi.com/search.json?engine=google_product&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&product_id=5687417807099585901"
#         },
#         {
#             "category": "Popular products",
#             "thumbnail": "https://encrypted-tbn2.gstatic.com/shopping?q=tbn:ANd9GcT0dTOmWGFfHJeRs-TULwDoS7rKx_25F6xNp-IAhb65U6PyIgbaT_2Wo8fS7jV5cl4oPOohl6J3vXZgtDHYPT64NLufrZSrf9qYvAOWNmrEqkCQJ3S-FpUaKA",
#             "source_logo": "https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn%3AANd9GcQpgfL0avcSnIIA7Wnlomi5kymZiO0A2kINnMkGZ3G1FlJRmOOARrbdPOOdSZARVbApsdeCP7QiIe5WxnPSOaIbtM4r",
#             "source": "Amazon",
#             "title": "12V 24V RS485 12CH 0-20MA Analog Digital PLC Remote I/O Module",
#             "price": "$12.98",
#             "extracted_price": 12.98,
#             "immersive_product_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...%3D%3D",
#             "product_id": "11851646069922540124",
#             "serpapi_product_api": "https://serpapi.com/search.json?engine=google_product&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&product_id=11851646069922540124"
#         },
#         {
#             "category": "Popular products",
#             "thumbnail": "https://encrypted-tbn1.gstatic.com/shopping?q=tbn:ANd9GcTuxSLLyUTnZIj_Odh2suRJ880xvHiLtUHrz7x7QvtNhNREE1gUQZypDxgJNT4kT1A95ts-mHumCYxUDP3AtQ-Swe-Bkvm0IExqBz8iwjyIoUGvP1VULXVM",
#             "source_logo": "https://encrypted-tbn0.gstatic.com/favicon-tbn?q=tbn%3AANd9GcRFVTy9QZt3kDLYr9MJ9HjiFK9XN6q3lhZCIuaSy0bY5HQWmcYvaJVKxtb77a2pOLmf272nBFk4QFmzQbSPzwV1yOZC7m5T",
#             "source": "ComWinTop",
#             "title": "CWT-BK-11040802 11Di/4Do/8Ai/2Ao Digital input and output Analog Input and Output Rs485 Modbus Rtu Io Module",
#             "price": "$61.80",
#             "extracted_price": 61.8,
#             "immersive_product_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...",
#             "product_id": "2509018237833314577",
#             "serpapi_product_api": "https://serpapi.com/search.json?engine=google_product&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&product_id=2509018237833314577"
#         },
#         {
#             "category": "Popular products",
#             "thumbnail": "https://encrypted-tbn0.gstatic.com/shopping?q=tbn:ANd9GcTBWedoUNRClGgNfqRuuNjZjxTfNc1PP_JjgAhd2W4yKNr-Licq4FGgdgTn7JSASgxdTEN-WYCtTXBt6lDcumQJ6kLgLI4GyW3B0ilMnSrqt3JsFlE4iNuPzQ",
#             "source_logo": "https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn%3AANd9GcQpgfL0avcSnIIA7Wnlomi5kymZiO0A2kINnMkGZ3G1FlJRmOOARrbdPOOdSZARVbApsdeCP7QiIe5WxnPSOaIbtM4r",
#             "source": "Amazon",
#             "title": "Modbus RTU IO Module 8AI4AO Analog Input and Output RTU PLC Expansion (Color : Compatible)",
#             "price": "$122.74",
#             "extracted_price": 122.74,
#             "immersive_product_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...%3D",
#             "product_id": "12088172726511525926",
#             "serpapi_product_api": "https://serpapi.com/search.json?engine=google_product&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&product_id=12088172726511525926"
#         },
#         {
#             "category": "Popular products",
#             "thumbnail": "https://encrypted-tbn2.gstatic.com/shopping?q=tbn:ANd9GcQyvQqtv3Qb4Ax8TAOKjJ9jQBb5YB60xOsbXeWuWnLo4v0xORNvJGIDqevEca6wym-MJ39p4NDXu4MqZyX7qQpoBq8UOgXHnUJH6qmFyM6gQUei_MGkzEP3",
#             "source_logo": "https://encrypted-tbn2.gstatic.com/favicon-tbn?q=tbn%3AANd9GcStSXIDaj71YsIPhNTSExhHzakjNUGyaAMz3P_x4eAAB9OInaPnUUkOYezwWeo85LJSxMDWgUrH0-GjGnKMeutGnw",
#             "source": "eBay",
#             "title": "RS485 Switch 20CH Digital Analog IO Module Modbus RTU PLC UART Expanding Board",
#             "price": "$38.32",
#             "extracted_price": 38.32,
#             "immersive_product_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...%3D%3D",
#             "product_id": "14935112485742883657",
#             "serpapi_product_api": "https://serpapi.com/search.json?engine=google_product&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&product_id=14935112485742883657"
#         },
#         {
#             "category": "Popular products",
#             "thumbnail": "https://encrypted-tbn2.gstatic.com/shopping?q=tbn:ANd9GcTBOaUuS6uWT5zg7dj__Dv8rzqxaXoWXrHqd1oZ96aBDpP2PQYjOiygGSiOanACqFZzMV19FATz1odHO-NAMwJpIxDSeoeRqCJ_bUu8cwwkAKQhPJHCP-iI",
#             "source_logo": "https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn%3AANd9GcQpgfL0avcSnIIA7Wnlomi5kymZiO0A2kINnMkGZ3G1FlJRmOOARrbdPOOdSZARVbApsdeCP7QiIe5WxnPSOaIbtM4r",
#             "source": "Amazon",
#             "title": "PLC Remote I/O Analog Digital IO Module",
#             "price": "$12.96",
#             "extracted_price": 12.96,
#             "immersive_product_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...%3D%3D",
#             "product_id": "15695031402926468423",
#             "serpapi_product_api": "https://serpapi.com/search.json?engine=google_product&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&product_id=15695031402926468423"
#         },
#         {
#             "category": "Popular products",
#             "thumbnail": "https://encrypted-tbn3.gstatic.com/shopping?q=tbn:ANd9GcShNjG4_ChqWWwkBL2LazgrTi6pHM-GdZhe0IYCHKZ72NE_ZTC6YJVphfpZNBaHqkmEm7EWfOQ6FhcvqsJcagJhcD56DUpcnBXKrwLi1NYT0nNBENfsHRXK",
#             "source_logo": "https://encrypted-tbn0.gstatic.com/favicon-tbn?q=tbn%3AANd9GcRFVTy9QZt3kDLYr9MJ9HjiFK9XN6q3lhZCIuaSy0bY5HQWmcYvaJVKxtb77a2pOLmf272nBFk4QFmzQbSPzwV1yOZC7m5T",
#             "source": "ComWinTop",
#             "title": "CWT-BK-04040802 4Di 4Do 8Ai 2Ao Digital input and output Analog Input and Output RS485 RS232 Ethernet Modbus Rtu Io Module",
#             "price": "$56.60",
#             "extracted_price": 56.6,
#             "immersive_product_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...%3D",
#             "product_id": "13596010028287498423",
#             "serpapi_product_api": "https://serpapi.com/search.json?engine=google_product&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&product_id=13596010028287498423"
#         },
#         {
#             "category": "Popular products",
#             "thumbnail": "https://encrypted-tbn3.gstatic.com/shopping?q=tbn:ANd9GcTKYjeggDy7V6m4g7OwBi0KyIzDsR-qa5P_HdqmEarbbMTAAZ-ISVo1-WwzAsh0Ov7ovoB0XeKMrD-vZTX3h9cOb8gomEadow51fo8c58To",
#             "source_logo": "https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn%3AANd9GcQpgfL0avcSnIIA7Wnlomi5kymZiO0A2kINnMkGZ3G1FlJRmOOARrbdPOOdSZARVbApsdeCP7QiIe5WxnPSOaIbtM4r",
#             "source": "Amazon",
#             "title": "4Di 4Do 8Ai 2Ao Digital Input and Output",
#             "price": "$126.19",
#             "extracted_price": 126.19,
#             "immersive_product_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...%3D",
#             "product_id": "17370877833628077635",
#             "serpapi_product_api": "https://serpapi.com/search.json?engine=google_product&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&product_id=17370877833628077635"
#         },
#         {
#             "category": "Popular products",
#             "thumbnail": "https://encrypted-tbn0.gstatic.com/shopping?q=tbn:ANd9GcS7mjjyb4TAkcnkrn__aBxLbImC3mXOvNWbJuwLEfvsIUJVaCFGgppijk__gPgTmL44H9ykjXdO0x0y5sdDHbqw2l8IAKWvv8SjNZYSTi4TCVUi4MS0TJ2Y",
#             "source_logo": "https://encrypted-tbn3.gstatic.com/favicon-tbn?q=tbn%3AANd9GcTlmZqkupJBUubloxCxqoRmLS_dWespgJwSgUhIJVlYQj6Cu_u4Tx7V6lktCFa4fSryvR4uvtZ5flfcfblXFdyZm_dvqYa77-4",
#             "source": "VP Process.Inc.",
#             "title": "Analog Input I/O Module",
#             "price": "$99.95",
#             "extracted_price": 99.95,
#             "immersive_product_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...%3D",
#             "product_id": "5119001464453348157",
#             "serpapi_product_api": "https://serpapi.com/search.json?engine=google_product&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&product_id=5119001464453348157"
#         },
#         {
#             "category": "Popular products",
#             "thumbnail": "https://encrypted-tbn0.gstatic.com/shopping?q=tbn:ANd9GcRRXHKdo3hINEC33rkqci3oIZ3u8fPTDiM4KK7ygwpBE8AkJiwAZPoxKQL2nazA6WppfqIgUj8vM62Z27cCV73ptQWJCdhMl3jZMuHBLzD1x_42lgJ4FXEY-A",
#             "source_logo": "https://encrypted-tbn1.gstatic.com/favicon-tbn?q=tbn%3AANd9GcQpgfL0avcSnIIA7Wnlomi5kymZiO0A2kINnMkGZ3G1FlJRmOOARrbdPOOdSZARVbApsdeCP7QiIe5WxnPSOaIbtM4r",
#             "source": "Amazon",
#             "title": "1PCS 4/8/16CH Digital Analog Ethernet Remote I/O Modules",
#             "price": "$94.40",
#             "extracted_price": 94.4,
#             "immersive_product_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...%3D",
#             "product_id": "11348878062788862223",
#             "serpapi_product_api": "https://serpapi.com/search.json?engine=google_product&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&product_id=11348878062788862223"
#         },
#         {
#             "category": "Popular products",
#             "thumbnail": "https://encrypted-tbn2.gstatic.com/shopping?q=tbn:ANd9GcRVIaNu237hMRO24YIQ2T9ISi37CT2_AUps_Yya30D_knDTfFTkGney__dEiM-Skd-D_hkLCUhP2GI4-CT6pOZuvxBsaxguBsA6nW3_9RUzkZ0FhAoi5VxXsA",
#             "source_logo": "https://encrypted-tbn0.gstatic.com/favicon-tbn?q=tbn%3AANd9GcRFVTy9QZt3kDLYr9MJ9HjiFK9XN6q3lhZCIuaSy0bY5HQWmcYvaJVKxtb77a2pOLmf272nBFk4QFmzQbSPzwV1yOZC7m5T",
#             "source": "ComWinTop",
#             "title": "CWT-BK-06040402 6Di 4Do 4Ai 2Ao Digital input and output Analog Input and Output RS485 RS232 Modbus Rtu Io Module",
#             "price": "$44.30",
#             "extracted_price": 44.3,
#             "immersive_product_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?engine=google_immersive_product&page_token=...",
#             "product_id": "8038423610188753504",
#             "serpapi_product_api": "https://serpapi.com/search.json?engine=google_product&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&product_id=8038423610188753504"
#         }
#     ],
#     "related_questions": [
#         {
#             "question": "What is the analog input of a RTU?",
#             "type": "featured_snippet",
#             "snippet": "What Is An Analog Input On An RTU? Analog inputs on a Remote Terminal Unit are used to precisely monitor continuously variable values of equipment connected to it (like temperature, relative humidity, and fuel tank levels).",
#             "title": "Analog Inputs for RTUs - DPS Telecom",
#             "link": "https://www.dpstele.com/rtu/analog-inputs.php#:~:text=What%20Is%20An%20Analog%20Input,%2C%20and%20fuel%20tank%20levels).",
#             "displayed_link": "https://www.dpstele.com \u203a rtu \u203a analog-inputs",
#             "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRKFt9RbKVbIjcGYlnrSeWqYOeDQCyHm0-W0fOMuwrs&s",
#             "source_logo": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/19a5a710298158bfe408bf896d710cf1218ff5f0c7387bae296f1c13ee8f9de6.png",
#             "next_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%3D%3D"
#         },
#         {
#             "question": "How to implement Modbus RTU protocol?",
#             "type": "featured_snippet",
#             "snippet": null,
#             "title": "Modbus RTU Frame Structure",
#             "date": "Jan 30, 2025",
#             "link": "https://www.wevolver.com/article/modbus-rtu-a-comprehensive-guide-to-understanding-and-implementing-the-protocol",
#             "list": [
#                 "Address Field (1 byte): Identifies the target slave device. ... ",
#                 "Function Code (1 byte): Indicates the type of action the master requests, such as reading or writing data.",
#                 "Data Field (N bytes): Contains the information relevant to the function, including register addresses and values."
#             ],
#             "displayed_link": "https://www.wevolver.com \u203a article \u203a modbus-rtu-a-com...",
#             "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSz7CeW_qrwOce8Na6PdJEIz4ptmxmjPSDGGp5Y0_JB&s",
#             "source_logo": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/19a5a710298158bfe408bf896d710cf10f36b81be167234b394509a07602b6f2.png",
#             "next_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=..."
#         },
#         {
#             "question": "What is the difference between 4 20mA and Modbus?",
#             "type": "featured_snippet",
#             "snippet": "Summary of Differences 4-20mA: An analog signaling standard for transmitting sensor data over a current loop. Each standard is used in industrial communication for different purposes: Modbus and RS-485 are primarily for digital communications, while 4-20mA is for analog signals.",
#             "title": "The difference between Modbus, RS485, and 4-20mA - Desun Uniwill",
#             "date": "Nov 25, 2024",
#             "link": "https://disen-sensor.com/the-difference-between-modbus-rs485-and-4-20ma/#:~:text=Summary%20of%20Differences,-Modbus%3A%20A%20protocol&text=4%2D20mA%3A%20An%20analog%20signaling,20mA%20is%20for%20analog%20signals.",
#             "displayed_link": "https://disen-sensor.com \u203a the-difference-between-modb...",
#             "source_logo": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/19a5a710298158bfe408bf896d710cf10576ab37bc88a826a403fecfc3eb0f7c.png",
#             "next_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=..."
#         },
#         {
#             "question": "Is Modbus RTU and RS-485 the same?",
#             "type": "featured_snippet",
#             "snippet": "The main difference is that Modbus articulates the protocol type, whereas RS485 defines the protocol's signal level. When using an RS485 communication device, the aforementioned distinction means that users should take some time to understand a bit about MODBUS protocol.",
#             "title": "RS485 vs Modbus Protocol. RS485 communication tutorial - Eltima",
#             "date": "Sep 26, 2021",
#             "link": "https://www.eltima.com/article/modbus-vs-rs485/#:~:text=The%20main%20difference%20is%20that,a%20bit%20about%20MODBUS%20protocol.",
#             "displayed_link": "https://www.eltima.com \u203a article \u203a modbus-vs-rs485",
#             "source_logo": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/19a5a710298158bfe408bf896d710cf19ae2cc5af46cd031b5d4ba323a16a9cf.png",
#             "next_page_token": "...",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google_related_questions&google_domain=google.com&next_page_token=...%3D%3D"
#         }
#     ],
#     "organic_results": [
#         {
#             "position": 1,
#             "title": "Modbus RTU Analog I/O",
#             "link": "https://www.acromag.com/product-category/signal-conditioners-network-i-o/modbus-rtu-io-modules/modbus-rtu-analog-i-o/",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.acromag.com/product-category/signal-conditioners-network-i-o/modbus-rtu-io-modules/modbus-rtu-analog-i-o/&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQFnoECBoQAQ",
#             "displayed_link": "https://www.acromag.com \u203a modbus-rtu-io-modules",
#             "thumbnail": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/c09c5cefae9bbd4074e2ead622572def22e390a2d396676e2c72cc76429363cc.jpeg",
#             "favicon": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/c09c5cefae9bbd4074e2ead622572defee262b7a0a7e66910e20923c301b292c.jpeg",
#             "snippet": "This signal conditioner is a two-channel analog input module with discrete outputs and Modbus communication. It conditions periodic or pulse waveform inputs and ...",
#             "snippet_highlighted_words": [
#                 "two-channel analog input module"
#             ],
#             "source": "Acromag"
#         },
#         {
#             "position": 2,
#             "title": "RS-485 I/O Modules",
#             "link": "https://buy.advantech.com/I-O-Devices-Communication/Remote-I-O-Modules-RS-485-I-O-Modules/Remote_RS-485_IO_Modules.products.htm",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://buy.advantech.com/I-O-Devices-Communication/Remote-I-O-Modules-RS-485-I-O-Modules/Remote_RS-485_IO_Modules.products.htm&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQFnoECDQQAQ",
#             "displayed_link": "https://buy.advantech.com \u203a ... \u203a Remote I/O Modules",
#             "thumbnail": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/c09c5cefae9bbd4074e2ead622572def425f23f6f512dc212a4f81c6fc844315.jpeg",
#             "favicon": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/c09c5cefae9bbd4074e2ead622572def5df0c5a62e0298b481b31f3209ddc677.png",
#             "snippet": "RS-485 I/O Modules \u00b7 16 channel digital input \u00b7 Protocols: Modbus RTU, ASCII \u00b7 Watchdog timer to recover the system \u00b7 2500VDC isolation protection.",
#             "snippet_highlighted_words": [
#                 "16 channel digital input"
#             ],
#             "rich_snippet": {
#                 "bottom": {
#                     "extensions": [
#                         "30-day returns"
#                     ]
#                 }
#             },
#             "source": "Advantech eStore"
#         },
#         {
#             "position": 3,
#             "title": "Lucid485-Serial RS-485 Analog / Digital IO Module",
#             "link": "https://www.lucid-control.com/lucid485-serial-rs-485-analog-digital-io-module-modbus-rtu/",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.lucid-control.com/lucid485-serial-rs-485-analog-digital-io-module-modbus-rtu/&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQFnoECDYQAQ",
#             "displayed_link": "https://www.lucid-control.com \u203a lucid485-serial-rs-485-a...",
#             "thumbnail": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/c09c5cefae9bbd4074e2ead622572defebfdc42f3b6915a2d4a6428f09e21369.jpeg",
#             "favicon": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/c09c5cefae9bbd4074e2ead622572def566b02e06866471be6ad2dc82c66cffd.png",
#             "snippet": "Lucid485 makes all analog and digital IO functions accessible by the serial RS-485 and Modbus RTU protocol. It integrates flawlessly into the product family and ...",
#             "snippet_highlighted_words": [
#                 "analog and digital",
#                 "Modbus RTU"
#             ],
#             "source": "LucidControl"
#         },
#         {
#             "position": 4,
#             "title": "Modbus digital Input Output Modules",
#             "link": "https://www.datexel.com/modbus-input-output-modules.html",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.datexel.com/modbus-input-output-modules.html&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQFnoECDMQAQ",
#             "displayed_link": "https://www.datexel.com \u203a modbus-input-output-modules",
#             "thumbnail": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/c09c5cefae9bbd4074e2ead622572def083c370fa55471af1fda873261a1e1d0.jpeg",
#             "favicon": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/c09c5cefae9bbd4074e2ead622572defdcf761a7bbe1269bcbfdd61caa61aa6f.png",
#             "snippet": "Modbus Digital Input Output Modules. The modules can accept digital inputs and provide outputs by way of relays, NPN or PNP transistors.",
#             "snippet_highlighted_words": [
#                 "Modbus Digital Input",
#                 "digital"
#             ],
#             "rich_snippet": {
#                 "bottom": {
#                     "detected_extensions": {
#                         "price_from": 81,
#                         "price_to": 175,
#                         "currency": "$"
#                     },
#                     "extensions": [
#                         "$81 to $175"
#                     ]
#                 }
#             },
#             "source": "Datexel"
#         },
#         {
#             "position": 5,
#             "title": "Tiny Modbus RTU Remote I/O Modules",
#             "link": "https://www.icpdas-usa.com/tiny-modbus-rtu-remote-io-modules.html?srsltid=AfmBOopDFrjN9EefIFR1Ll0PwT5wmCIe7UgQWTjeXkLWCmHAZxKrTyOu",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.icpdas-usa.com/tiny-modbus-rtu-remote-io-modules.html%3Fsrsltid%3DAfmBOopDFrjN9EefIFR1Ll0PwT5wmCIe7UgQWTjeXkLWCmHAZxKrTyOu&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQFnoECDcQAQ",
#             "displayed_link": "https://www.icpdas-usa.com \u203a tiny-modbus-rtu-remote-i...",
#             "thumbnail": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/c09c5cefae9bbd4074e2ead622572def82db9ad15c7cc6a842762d2a70d8ba53.jpeg",
#             "favicon": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/c09c5cefae9bbd4074e2ead622572def5e259bcebe9613d6b8d3efeed530fb00.png",
#             "snippet": "Modbus RTU and/or DCON remote I/O modules in a \"tiny\" form-fitting package. Easily integrate with the existing serial networks while saving space.",
#             "snippet_highlighted_words": [
#                 "Modbus RTU and/or DCON remote I/O modules"
#             ],
#             "source": "ICP DAS USA"
#         },
#         {
#             "position": 6,
#             "title": "Analog to Modbus Serial Interface Modules",
#             "link": "https://www.dwyeromega.com/en-us/analog-to-modbus-serial-interface-modules/p/D6000-Series?srsltid=AfmBOop-Ahultg5yZ72PtM3jqZaDRslK20-uRHqWtHnh-QO9pXzMjg3M",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.dwyeromega.com/en-us/analog-to-modbus-serial-interface-modules/p/D6000-Series%3Fsrsltid%3DAfmBOop-Ahultg5yZ72PtM3jqZaDRslK20-uRHqWtHnh-QO9pXzMjg3M&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQFnoECDsQAQ",
#             "displayed_link": "https://www.dwyeromega.com \u203a en-us \u203a D6000-Series",
#             "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQcCul1md-QcNfyZoPjB4LRYdRBdGYpdyQtWhFYGXxekbHBm02bOv8e&s",
#             "favicon": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/c09c5cefae9bbd4074e2ead622572def2daede7df23aea3ece79b449028a184d.png",
#             "snippet": "The analog input modules output the resultant digital data as unsigned integer percentage of full-scale values that are compatible with the MODBUS RTU protocol.",
#             "snippet_highlighted_words": [
#                 "analog input",
#                 "digital",
#                 "MODBUS RTU"
#             ],
#             "rich_snippet": {
#                 "bottom": {
#                     "detected_extensions": {
#                         "price": 418.2,
#                         "currency": "$"
#                     },
#                     "extensions": [
#                         "$418.20",
#                         "Out of stock"
#                     ]
#                 }
#             },
#             "source": "Dwyer Instruments"
#         },
#         {
#             "position": 7,
#             "title": "Modbus RTU I/O module",
#             "link": "https://www.directindustry.com/industrial-manufacturer/modbus-rtu-i-o-module-237875.html",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.directindustry.com/industrial-manufacturer/modbus-rtu-i-o-module-237875.html&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQFnoECEYQAQ",
#             "displayed_link": "https://www.directindustry.com \u203a Automation",
#             "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS7YXSb2UyYinAmw5VR-2IVzQlEII2aYLrpeQLTbPAeFj9Yu8PAMIrbgFBrcwg79BVi1Q&s",
#             "favicon": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/c09c5cefae9bbd4074e2ead622572def654c3f781cee0b5947ff3d7d9a020faf.png",
#             "snippet": "Z-4DI-2AI-2DO is a I/O module with 4 digital inputs, 2 analog inputs, 2 relay outputs, slave for Modbus RTU, on two RS485 serial ports. The module allows the ...",
#             "snippet_highlighted_words": [
#                 "4 digital inputs, 2 analog inputs"
#             ],
#             "images": [
#                 "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS7YXSb2UyYinAmw5VR-2IVzQlEII2aYLrpeQLTbPAeFj9Yu8PAMIrbgFBrcwg79BVi1Q&s"
#             ],
#             "rich_snippet": {
#                 "bottom": {
#                     "extensions": [
#                         "Free delivery"
#                     ]
#                 }
#             },
#             "source": "DirectIndustry"
#         },
#         {
#             "position": 8,
#             "title": "Recommended Low-Cost Modbus RTU Mixed-Signal ...",
#             "link": "https://control.com/forums/threads/recommended-low-cost-modbus-rtu-mixed-signal-remote-i-o-module.44544/",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://control.com/forums/threads/recommended-low-cost-modbus-rtu-mixed-signal-remote-i-o-module.44544/&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQFnoECDEQAQ",
#             "displayed_link": "https://control.com \u203a ... \u203a Communication \u203a Modbus",
#             "favicon": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/c09c5cefae9bbd4074e2ead622572def3762b1b9e4a509d698dda0ecdf0ede96.png",
#             "date": "Nov 5, 2015",
#             "snippet": "My company is looking for a simple, low cost Modbus RTU remote IO module with digital in/out (1 ea), analog in/out (1 ea), and relay outputs (1-2).",
#             "snippet_highlighted_words": [
#                 "Modbus RTU",
#                 "digital",
#                 "analog"
#             ],
#             "source": "Control.com"
#         },
#         {
#             "position": 9,
#             "title": "I/O ModBUS RTU Systems | Analog I/O Modules",
#             "link": "https://www.seneca.it/en/linee-di-prodotto/acquisizione-dati-e-automazione/sistemi-io-modbus-rtu/moduli-io-analogici/?srsltid=AfmBOorqp8SIK8f5lXW8Wci9-fVuLIGpM9aJwx6djSzyhWQhQ4eUnl2U",
#             "redirect_link": "https://www.google.com/url?sa=t&source=web&rct=j&opi=89978449&url=https://www.seneca.it/en/linee-di-prodotto/acquisizione-dati-e-automazione/sistemi-io-modbus-rtu/moduli-io-analogici/%3Fsrsltid%3DAfmBOorqp8SIK8f5lXW8Wci9-fVuLIGpM9aJwx6djSzyhWQhQ4eUnl2U&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQFnoECDIQAQ",
#             "displayed_link": "https://www.seneca.it \u203a moduli-io-analogici",
#             "thumbnail": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTnePMspPt3JUB6W0bKvtCUQo0w2dKFHUgsvxWoii1rv8xMSbHyTQBYlw&s",
#             "favicon": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/c09c5cefae9bbd4074e2ead622572defd4e081a8b554891abe8ee51a70960fac.png",
#             "snippet": "2 CH Analog input Modbus RTU - Modbus TCP-IP module. ZE-2AI is an I/O module with 2 analog inputs for slave communication over Modbus.",
#             "snippet_highlighted_words": [
#                 "2 CH Analog input Modbus RTU"
#             ],
#             "source": "seneca.it"
#         }
#     ],
#     "related_searches": [
#         {
#             "block_position": 1,
#             "query": "Modbus analog Input module",
#             "link": "https://www.google.com/search?sca_esv=9cb49794e0b2005d&gl=us&hl=en&q=Modbus+analog+Input+module&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ1QJ6BAhuEAE",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=Modbus+analog+Input+module"
#         },
#         {
#             "block_position": 1,
#             "query": "Waveshare Modbus RTU Analog Input 8CH",
#             "link": "https://www.google.com/search?sca_esv=9cb49794e0b2005d&gl=us&hl=en&q=Waveshare+Modbus+RTU+Analog+Input+8CH&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ1QJ6BAhnEAE",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=Waveshare+Modbus+RTU+Analog+Input+8CH"
#         },
#         {
#             "block_position": 1,
#             "query": "Analog input module working principle",
#             "link": "https://www.google.com/search?sca_esv=9cb49794e0b2005d&gl=us&hl=en&q=Analog+input+module+working+principle&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ1QJ6BAhmEAE",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=Analog+input+module+working+principle"
#         },
#         {
#             "block_position": 1,
#             "query": "Analog input module in PLC",
#             "link": "https://www.google.com/search?sca_esv=9cb49794e0b2005d&gl=us&hl=en&q=Analog+input+module+in+PLC&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ1QJ6BAhlEAE",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=Analog+input+module+in+PLC"
#         },
#         {
#             "block_position": 1,
#             "query": "Modbus digital input module",
#             "link": "https://www.google.com/search?sca_esv=9cb49794e0b2005d&gl=us&hl=en&q=Modbus+digital+input+module&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ1QJ6BAhkEAE",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=Modbus+digital+input+module"
#         },
#         {
#             "block_position": 1,
#             "query": "Acromag Ethernet I/O modules",
#             "link": "https://www.google.com/search?sca_esv=9cb49794e0b2005d&gl=us&hl=en&q=Acromag+Ethernet+I/O+modules&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ1QJ6BAhjEAE",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=Acromag+Ethernet+I%2FO+modules"
#         },
#         {
#             "block_position": 1,
#             "query": "Analog input module Siemens",
#             "link": "https://www.google.com/search?sca_esv=9cb49794e0b2005d&gl=us&hl=en&q=Analog+input+module+Siemens&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ1QJ6BAhiEAE",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=Analog+input+module+Siemens"
#         },
#         {
#             "block_position": 1,
#             "query": "RTD Modbus RTU",
#             "link": "https://www.google.com/search?sca_esv=9cb49794e0b2005d&gl=us&hl=en&q=RTD+Modbus+RTU&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ1QJ6BAhgEAE",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=RTD+Modbus+RTU"
#         }
#     ],
#     "refine_this_search": [
#         {
#             "query": "Nearby",
#             "link": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu+nearby&gl=us&hl=en&shoprs=CAEYAyokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MgwIAxIGTmVhcmJ5GAJYj6whYAE&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQip4GKAF6BAgZEDM",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu+nearby"
#         },
#         {
#             "query": "Price",
#             "link": "https://www.google.com/search?q=price+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYEiokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MgkIEhIFUHJpY2VgAQ&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQip4GKAJ6BAgZEDQ",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=price+analog+and+digital+i+o+to+modbus+rtu"
#         },
#         {
#             "query": "For Sale",
#             "link": "https://www.google.com/search?q=analog+and+digital+i+o+to+modbus+rtu+for+sale&gl=us&hl=en&shoprs=CAEYEiokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MgwIEhIIRm9yIFNhbGVgAQ&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQip4GKAN6BAgZEDU",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i+o+to+modbus+rtu+for+sale"
#         },
#         {
#             "query": "Free",
#             "link": "https://www.google.com/search?q=free+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYEiokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MggIEhIERnJlZWAB&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQip4GKAR6BAgZEDY",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=free+analog+and+digital+i+o+to+modbus+rtu"
#         },
#         {
#             "query": "Buy",
#             "link": "https://www.google.com/search?q=buy+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYEiokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MgcIEhIDQnV5YAE&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQip4GKAV6BAgZEDc",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=buy+analog+and+digital+i+o+to+modbus+rtu"
#         },
#         {
#             "query": "Online",
#             "link": "https://www.google.com/search?q=online+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYEiokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MgoIEhIGT25saW5lYAE&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQip4GKAZ6BAgZEDg",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=online+analog+and+digital+i+o+to+modbus+rtu"
#         },
#         {
#             "query": "Amazon",
#             "link": "https://www.google.com/search?q=amazon+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYAiokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MgoIAhIGQW1hem9uWI-sIWAB&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQip4GKAd6BAgZEDk",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=amazon+analog+and+digital+i+o+to+modbus+rtu",
#             "thumbnail": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/5dccfabbcd9aac2a9cce7eee39d21f0eafe8e3e9add078e3a7e212545f33964b.png"
#         },
#         {
#             "query": "Blue",
#             "link": "https://www.google.com/search?q=blue+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYASokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhYIARIEQmx1ZToMCNiM9QEQ5or1ATALWI-sIWAB&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQip4GKAh6BAgZEDs",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=blue+analog+and+digital+i+o+to+modbus+rtu"
#         },
#         {
#             "query": "Green",
#             "link": "https://www.google.com/search?q=green+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYASokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhcIARIFR3JlZW46DAjYjPUBEOiK9QEwC1iPrCFgAQ&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQip4GKAl6BAgZEDw",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=green+analog+and+digital+i+o+to+modbus+rtu"
#         },
#         {
#             "query": "Gray",
#             "link": "https://www.google.com/search?q=gray+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYASokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhYIARIER3JheToMCNiM9QEQ6or1ATALWI-sIWAB&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQip4GKAp6BAgZED0",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=gray+analog+and+digital+i+o+to+modbus+rtu"
#         },
#         {
#             "query": "Black",
#             "link": "https://www.google.com/search?q=black+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYASokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhcIARIFQmxhY2s6DAjYjPUBEOWK9QEwC1iPrCFgAQ&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQip4GKAt6BAgZED4",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=black+analog+and+digital+i+o+to+modbus+rtu"
#         },
#         {
#             "query": "Brown",
#             "link": "https://www.google.com/search?q=brown+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYASokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhcIARIFQnJvd246DAjYjPUBEOuK9QEwC1iPrCFgAQ&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQip4GKAx6BAgZED8",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=brown+analog+and+digital+i+o+to+modbus+rtu"
#         },
#         {
#             "query": "Under $45",
#             "link": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu+under+$45&gl=us&hl=en&shoprs=CAESDRILEQAAAAAqdYVBGAEYBSokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MiIIBRIJVW5kZXIgJDQ1GAIiDRILEQAAAAAqdYVBGAEqAhgBWI-sIWAB&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQip4GKA16BAgZEEA",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu+under+%2445"
#         },
#         {
#             "query": "New",
#             "link": "https://www.google.com/search?q=new+analog+and+digital+i/o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYCiokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MgcIChIDTmV3WI-sIWAB&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQip4GKA56BAgZEEE",
#             "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=new+analog+and+digital+i%2Fo+to+modbus+rtu",
#             "thumbnail": "https://serpapi.com/searches/6879ed6c018c48d204358bb1/images/5dccfabbcd9aac2a9cce7eee39d21f0e5e3c10cbb35704d525c0ac8e9e513c28.svg+xml"
#         },
#         {
#             "query": "Used",
# ...
#                 },
#                 {
#                     "title": "Banner Engineering",
#                     "link": "https://www.google.com/search?q=banner+engineering+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYAiokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhYIAhISQmFubmVyIEVuZ2luZWVyaW5nWI-sIWAC&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAN6BAgZEAo",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=banner+engineering+analog+and+digital+i+o+to+modbus+rtu"
#                 },
#                 {
#                     "title": "icpdas-usa.com",
#                     "link": "https://www.google.com/search?q=icpdas-usa.com+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYAiokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhIIAhIOaWNwZGFzLXVzYS5jb21Yj6whYAI&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAR6BAgZEAs",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=icpdas-usa.com+analog+and+digital+i+o+to+modbus+rtu"
#                 }
#             ]
#         },
#         {
#             "type": "Color",
#             "options": [
#                 {
#                     "title": "Blue",
#                     "link": "https://www.google.com/search?q=blue+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYASokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhYIARIEQmx1ZToMCNiM9QEQ5or1ATALWI-sIWAC&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAB6BAgZEA8",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=blue+analog+and+digital+i+o+to+modbus+rtu"
#                 },
#                 {
#                     "title": "Green",
#                     "link": "https://www.google.com/search?q=green+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYASokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhcIARIFR3JlZW46DAjYjPUBEOiK9QEwC1iPrCFgAg&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAF6BAgZEBA",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=green+analog+and+digital+i+o+to+modbus+rtu"
#                 },
#                 {
#                     "title": "Gray",
#                     "link": "https://www.google.com/search?q=gray+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYASokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhYIARIER3JheToMCNiM9QEQ6or1ATALWI-sIWAC&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAJ6BAgZEBE",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=gray+analog+and+digital+i+o+to+modbus+rtu"
#                 },
#                 {
#                     "title": "Black",
#                     "link": "https://www.google.com/search?q=black+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYASokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhcIARIFQmxhY2s6DAjYjPUBEOWK9QEwC1iPrCFgAg&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAN6BAgZEBI",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=black+analog+and+digital+i+o+to+modbus+rtu"
#                 }
#             ]
#         },
#         {
#             "type": "Price",
#             "options": [
#                 {
#                     "title": "Under $45",
#                     "link": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu+under+$45&gl=us&hl=en&shoprs=CAESDRILEQAAAAAqdYVBGAEYBSokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MiIIBRIJVW5kZXIgJDQ1GAIiDRILEQAAAAAqdYVBGAEqAhgBWI-sIWAC&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAB6BAgZEBg",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu+under+%2445"
#                 },
#                 {
#                     "title": "$45 - $100",
#                     "link": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu+between+$45+and+$100&gl=us&hl=en&shoprs=CAESFhIUCQAAAAAqdYVBEQAAAACE15dBGAEYBSokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MiwIBRIKJDQ1IC0gJDEwMBgCIhYSFAkAAAAAKnWFQREAAAAAhNeXQRgBKgIYAViPrCFgAg&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAF6BAgZEBk",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu+between+%2445+and+%24100"
#                 },
#                 {
#                     "title": "$100 - $200",
#                     "link": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu+between+$100+and+$200&gl=us&hl=en&shoprs=CAESFhIUCQAAAACE15dBEQAAAACE16dBGAEYBSokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1Mi0IBRILJDEwMCAtICQyMDAYAiIWEhQJAAAAAITXl0ERAAAAAITXp0EYASoCGAFYj6whYAI&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAJ6BAgZEBo",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu+between+%24100+and+%24200"
#                 },
#                 {
#                     "title": "Over $200",
#                     "link": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu+over+$200&gl=us&hl=en&shoprs=CAESDRILCQAAAACE16dBGAEYBSokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MiIIBRIJT3ZlciAkMjAwGAIiDRILCQAAAACE16dBGAEqAhgBWI-sIWAC&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAN6BAgZEBs",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu+over+%24200"
#                 }
#             ]
#         },
#         {
#             "type": "Sort by",
#             "options": [
#                 {
#                     "title": "Price: low to high",
#                     "link": "https://www.google.com/search?q=analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYFyokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhwIFxISUHJpY2U6IGxvdyB0byBoaWdoKgQQARgBYAKIAQE&udm=3&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAB6BAgZECI",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i+o+to+modbus+rtu"
#                 },
#                 {
#                     "title": "Price: high to low",
#                     "link": "https://www.google.com/search?q=analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYFyokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhwIFxISUHJpY2U6IGhpZ2ggdG8gbG93KgQQARgBYAKIAQI&udm=3&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAF6BAgZECM",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i+o+to+modbus+rtu"
#                 }
#             ]
#         },
#         {
#             "type": "Free shipping",
#             "options": [
#                 {
#                     "title": "Free shipping",
#                     "link": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu+free+shipping&gl=us&hl=en&shoprs=CAESBFICEAEYGSokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhcIGRINRnJlZSBzaGlwcGluZyIEUgIQAWAC&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAB6BAgZECc",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu+free+shipping"
#                 }
#             ]
#         },
#         {
#             "type": "Brand",
#             "options": [
#                 {
#                     "title": "Banner",
#                     "link": "https://www.google.com/search?q=banner+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYASokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhYIARIGQmFubmVyOgoIg_M8EJe4TzABWI-sIWAC&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAB6BAgZECs",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=banner+analog+and+digital+i+o+to+modbus+rtu"
#                 },
#                 {
#                     "title": "ICP DAS USA",
#                     "link": "https://www.google.com/search?q=icp+das+usa+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYASokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MhwIARILSUNQIERBUyBVU0E6CwiD8zwQnKPTAjABWI-sIWAC&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAF6BAgZECw",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=icp+das+usa+analog+and+digital+i+o+to+modbus+rtu"
#                 },
#                 {
#                     "title": "OMEGA Engineering",
#                     "link": "https://www.google.com/search?q=omega+engineering+analog+and+digital+i+o+to+modbus+rtu&gl=us&hl=en&shoprs=CAEYASokYW5hbG9nIGFuZCBkaWdpdGFsIGkgbyB0byBtb2RidXMgcnR1MiEIARIRT01FR0EgRW5naW5lZXJpbmc6CgiD8zwQhu1EMAFYj6whYAI&sa=X&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ268JKAJ6BAgZEC0",
#                     "serpapi_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=omega+engineering+analog+and+digital+i+o+to+modbus+rtu"
#                 }
#             ]
#         }
#     ],
#     "pagination": {
#         "current": 1,
#         "next": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu&sca_esv=9cb49794e0b2005d&gl=us&hl=en&ei=hu15aO_bJ9KqqtsPpIbruA0&start=10&sa=N&sstk=Ac65TH572F5RSquGfivyN70wyzYzI9co8WPZr25sCGk1bS00qTbNgfSw10smu0KEzvS2Gz1uCJLM3ppt_cRR_aNVcmDw8Rw5aLAq-Q&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ8NMDegQIBxAW",
#         "other_pages": {
#             "2": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu&sca_esv=9cb49794e0b2005d&gl=us&hl=en&ei=hu15aO_bJ9KqqtsPpIbruA0&start=10&sa=N&sstk=Ac65TH572F5RSquGfivyN70wyzYzI9co8WPZr25sCGk1bS00qTbNgfSw10smu0KEzvS2Gz1uCJLM3ppt_cRR_aNVcmDw8Rw5aLAq-Q&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ8tMDegQIBxAE",
#             "3": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu&sca_esv=9cb49794e0b2005d&gl=us&hl=en&ei=hu15aO_bJ9KqqtsPpIbruA0&start=20&sa=N&sstk=Ac65TH572F5RSquGfivyN70wyzYzI9co8WPZr25sCGk1bS00qTbNgfSw10smu0KEzvS2Gz1uCJLM3ppt_cRR_aNVcmDw8Rw5aLAq-Q&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ8tMDegQIBxAG",
#             "4": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu&sca_esv=9cb49794e0b2005d&gl=us&hl=en&ei=hu15aO_bJ9KqqtsPpIbruA0&start=30&sa=N&sstk=Ac65TH572F5RSquGfivyN70wyzYzI9co8WPZr25sCGk1bS00qTbNgfSw10smu0KEzvS2Gz1uCJLM3ppt_cRR_aNVcmDw8Rw5aLAq-Q&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ8tMDegQIBxAI",
#             "5": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu&sca_esv=9cb49794e0b2005d&gl=us&hl=en&ei=hu15aO_bJ9KqqtsPpIbruA0&start=40&sa=N&sstk=Ac65TH572F5RSquGfivyN70wyzYzI9co8WPZr25sCGk1bS00qTbNgfSw10smu0KEzvS2Gz1uCJLM3ppt_cRR_aNVcmDw8Rw5aLAq-Q&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ8tMDegQIBxAK",
#             "6": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu&sca_esv=9cb49794e0b2005d&gl=us&hl=en&ei=hu15aO_bJ9KqqtsPpIbruA0&start=50&sa=N&sstk=Ac65TH572F5RSquGfivyN70wyzYzI9co8WPZr25sCGk1bS00qTbNgfSw10smu0KEzvS2Gz1uCJLM3ppt_cRR_aNVcmDw8Rw5aLAq-Q&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ8tMDegQIBxAM",
#             "7": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu&sca_esv=9cb49794e0b2005d&gl=us&hl=en&ei=hu15aO_bJ9KqqtsPpIbruA0&start=60&sa=N&sstk=Ac65TH572F5RSquGfivyN70wyzYzI9co8WPZr25sCGk1bS00qTbNgfSw10smu0KEzvS2Gz1uCJLM3ppt_cRR_aNVcmDw8Rw5aLAq-Q&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ8tMDegQIBxAO",
#             "8": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu&sca_esv=9cb49794e0b2005d&gl=us&hl=en&ei=hu15aO_bJ9KqqtsPpIbruA0&start=70&sa=N&sstk=Ac65TH572F5RSquGfivyN70wyzYzI9co8WPZr25sCGk1bS00qTbNgfSw10smu0KEzvS2Gz1uCJLM3ppt_cRR_aNVcmDw8Rw5aLAq-Q&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ8tMDegQIBxAQ",
#             "9": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu&sca_esv=9cb49794e0b2005d&gl=us&hl=en&ei=hu15aO_bJ9KqqtsPpIbruA0&start=80&sa=N&sstk=Ac65TH572F5RSquGfivyN70wyzYzI9co8WPZr25sCGk1bS00qTbNgfSw10smu0KEzvS2Gz1uCJLM3ppt_cRR_aNVcmDw8Rw5aLAq-Q&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ8tMDegQIBxAS",
#             "10": "https://www.google.com/search?q=analog+and+digital+i/o+to+modbus+rtu&sca_esv=9cb49794e0b2005d&gl=us&hl=en&ei=hu15aO_bJ9KqqtsPpIbruA0&start=90&sa=N&sstk=Ac65TH572F5RSquGfivyN70wyzYzI9co8WPZr25sCGk1bS00qTbNgfSw10smu0KEzvS2Gz1uCJLM3ppt_cRR_aNVcmDw8Rw5aLAq-Q&ved=2ahUKEwjvtu_E58WOAxVSlWoFHSTDGtcQ8tMDegQIBxAU"
#         }
#     },
#     "serpapi_pagination": {
#         "current": 1,
#         "next_link": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu&start=10",
#         "next": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu&start=10",
#         "other_pages": {
#             "2": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu&start=10",
#             "3": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu&start=20",
#             "4": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu&start=30",
#             "5": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu&start=40",
#             "6": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu&start=50",
#             "7": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu&start=60",
#             "8": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu&start=70",
#             "9": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu&start=80",
#             "10": "https://serpapi.com/search.json?device=desktop&engine=google&gl=us&google_domain=google.com&hl=en&location=Austin%2C+Texas%2C+United+States&q=analog+and+digital+i%2Fo+to+modbus+rtu&start=90"
#         }
#     }
# }

# %%
extract_model_info("https://www.plc-io.com/it/home/moduli-i-o/products.1.5.2.sp.uw?l=2&gad_source=1&gad_campaignid=714218552&gbraid=0AAAAADql6FQ8HZRQKO3j8iSICJ5NqYvu4&gclid=CjwKCAjwvuLDBhAOEiwAPtF0VmCqa9lidhuz5PK8F1NEczfUSfVk5IBb-tRI-Ll3aE4qlByG2N0meBoCr8UQAvD_BwE")
# Out:
# []
