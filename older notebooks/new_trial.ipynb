# %%
with open('description.txt', 'r') as file:
    text = file.read()

# %%
import json
import re

# First, let's clean and parse the JSON data properly
def clean_json_data(text):
    """Clean the JSON string and parse it properly"""
    # Remove unicode characters like \u00a0
    cleaned_text = re.sub(r'\\u00a0', '', text)
    # Parse the JSO
    data = json.loads(cleaned_text)
    return data

# Clean the data
products = clean_json_data(text)
print(f"Found {len(products)} products")
print(f"First product model: {products[0]['model_no']}")
# Out:
# Found 100 products
# First product model: I-7547

# %%
def parse_description(desc):
    # Extract short and full descriptions separately
    full_desc_match = re.search(r"Full Description:\s*(.*?)(?:\.|$)", desc)
    short_desc_match = re.search(r"Short Description:\s*(.*?)(?:\.|$)", desc)
    
    # Extract all other key-value style entries
    key_value_pairs = re.findall(r"([\w\s/]+?):\s*(.*?)(?:\.|$)", desc)

    parsed = {
        "full_description": full_desc_match.group(1) if full_desc_match else "",
        # "short_description": short_desc_match.group(1) if short_desc_match else "",
        "specs": {k.strip(): v.strip() for k, v in key_value_pairs 
                  if k not in ["Full Description", "Short Description"]}
    }
    return parsed

# Apply parsing
for item in products:
    parsed = parse_description(item["description"])
    item["full_description"] = parsed["full_description"]
    # item["short_description"] = parsed["short_description"]
    item["specs"] = parsed["specs"]
    del item["description"]
    specs = item.get("specs", {})
    if "Fi" in specs:
        # Move value to correct key
        specs["Wi-Fi"] = specs.pop("Fi")

# %%
def clean_spec_value(key, value):
    value = value.strip()
    
    # Normalize "No XYZ support" → "not supported"
    if re.match(r'no\s+[a-zA-Z0-9\-/ ]+\s+support', value, flags=re.IGNORECASE):
        return "not supported"
    
    # Normalize "XYZ not available" → "not available"
    if re.search(r'not available', value, flags=re.IGNORECASE):
        return "not available"

    return value

def specs_to_string(specs):
    parts = []
    for k, v in specs.items():
        cleaned = clean_spec_value(k, v)
        parts.append(f"{k}: {cleaned}")
    return ". ".join(parts)

# %%
products
# Out:
# [{'model_no': 'I-7547',
#   'full_description': 'Ethernet(TCP/IP) to HART Converter',
#   'specs': {'Short Description': 'HART Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCI and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 HART devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports HART input protocol',
#    'Output Protocol': 'Supports Ethernet TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7567',
#   'full_description': 'USB to HART converter',
#   'specs': {'Short Description': 'HART Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 HART devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports HART input protocol',
#    'Output Protocol': 'Supports USB output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7570',
#   'full_description': 'Serial to HART converter',
#   'specs': {'Short Description': 'HART Converter',
#    'Serial Port': 'Supports RS232, RS422, and RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 HART devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports HART input protocol',
#    'Output Protocol': 'Supports RS232, RS485, and RS422 output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'HRT-227CS',
#   'full_description': 'HART to Single Mode Fiber Converter',
#   'specs': {'Short Description': 'HART Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 HART devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports HART input protocol',
#    'Output Protocol': 'Supports FIBER output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'HRT-710',
#   'full_description': 'Modbus/RTU & ASCII to HART gateway',
#   'specs': {'Short Description': 'HART Gateway',
#    'Serial Port': 'Supports RS232 and RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 HART devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports HART input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'HRT-711',
#   'full_description': 'Modbus TCP/UDP to HART Gateway',
#   'specs': {'Short Description': 'HART Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 HART devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports HART input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7550-B',
#   'full_description': 'PROFIBUS to RS-232/422/485 Converter(Plastic Case)',
#   'specs': {'Short Description': 'Profibus Converter',
#    'Serial Port': 'Supports RS232, RS422, and RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profibus DP input protocol',
#    'Output Protocol': 'Supports RS232, RS485, and RS422 output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7550E',
#   'full_description': 'PROFIBUS to Ethernet Converter(Plastic Case)',
#   'specs': {'Short Description': 'Profibus Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 6 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profibus DP input protocol',
#    'Output Protocol': 'Supports TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'PROFI-2510',
#   'full_description': 'Isolated PROFIBUS Repeater',
#   'specs': {'Short Description': 'Profibus Repeater',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 15 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profibus DP input protocol',
#    'Output Protocol': 'Supports Profibus DP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'PROFI-2541-SC',
#   'full_description': 'PROFIBUS DP to Multi-mode Fiber Converter (SC-Type)',
#   'specs': {'Short Description': 'Profibus Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 15 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profibus DP input protocol',
#    'Output Protocol': 'Supports FIBER output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'GW-7552-B',
#   'full_description': 'PROFIBUS to Modbus Gateway (Plastic Case)',
#   'specs': {'Short Description': 'Profibus Gateway',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profibus DP input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'GW-7553-B',
#   'full_description': 'PROFIBUS to Modbus TCP Gateway (Plastic Case)',
#   'specs': {'Short Description': 'Profibus Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profibus DP input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'GW-7553-CPM',
#   'full_description': 'PROFIBUS to CANopen Gateway (Plastic Case)',
#   'specs': {'Short Description': 'CANopen Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profibus DP input protocol',
#    'Output Protocol': 'Supports CANOpen output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7580',
#   'full_description': 'PROFINET to RS-232/422/485 Converter',
#   'specs': {'Short Description': 'Profinet Converter',
#    'Serial Port': 'Supports RS232, RS485, and RS422 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profinet input protocol',
#    'Output Protocol': 'Supports RS232, RS485, and RS422 output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'GW-7662',
#   'full_description': 'PROFINET to Modbus RTU/ASCII Gateway',
#   'specs': {'Short Description': 'Profinet Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profinet input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'GW-7663',
#   'full_description': 'PROFINET to Modbus TCP Gateway',
#   'specs': {'Short Description': 'Profinet Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profinet input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-2533CS',
#   'full_description': 'CAN to Single-mode Fiber Bridge; 1 (30 km) single-mode, SC connector',
#   'specs': {'Short Description': 'CAN Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1 CAN device',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANBus input protocol',
#    'Output Protocol': 'Supports FIBER output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7531-FD-G',
#   'full_description': 'Two-channel Isolated CAN / CAN FD Signal Repeater',
#   'specs': {'Short Description': 'CAN Repeater',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 2 CAN devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANBus input protocol',
#    'Output Protocol': 'Supports CANBus output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7530A-G',
#   'full_description': 'Intelligent RS-232/485/422 to CAN converter',
#   'specs': {'Short Description': 'CAN Converter',
#    'Serial Port': 'Supports RS232, RS422, and RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 CAN devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANBus input protocol',
#    'Output Protocol': 'Supports RS232, RS485, and RS422 output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7530A-MR-FD',
#   'full_description': 'Modbus RTU to CAN Converter',
#   'specs': {'Short Description': 'CAN Gateway',
#    'Serial Port': 'Supports RS232, RS422, and RS486 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 CAN devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANBus input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7540D-MTCP-G',
#   'full_description': 'CAN to Ethernet / Modbus TCP / Modbus RTU Converter (Plastic Case)',
#   'specs': {'Short Description': 'CAN Gateway',
#    'Serial Port': 'Supports RS232 and RS485 serial port',
#    'Ethernet': 'Supports Modbus TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 CAN devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANBus input protocol',
#    'Output Protocol': 'Supports Modbus RTU and TCPIP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7565-H2-G',
#   'full_description': 'High Performance Intelligent USB to 2-port CAN bus converter (Plastic Case)',
#   'specs': {'Short Description': 'CAN Bus Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 2 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANBus input protocol',
#    'Output Protocol': 'Supports USB output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'ECAN-240-FD',
#   'full_description': 'Modbus TCP to 2-port CAN FD Gateway',
#   'specs': {'Short Description': 'CAN Bus Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports Modbus TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 2 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANBus input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'GW-7433D',
#   'full_description': 'Modbus TCP server/RTU slave to CANopen Master Gateway',
#   'specs': {'Short Description': 'CANopen Gateway',
#    'Serial Port': 'Supports RS232 and RS485 serial port',
#    'Ethernet': 'Supports Modbus TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 CAN devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANOpen input protocol',
#    'Output Protocol': 'Supports Modbus RTU and TCPIP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'GW-2492M',
#   'full_description': 'BACnet/IP Server to Modbus RTU Master Gateway',
#   'specs': {'Short Description': 'BACnet/IP Gateway',
#    'Serial Port': 'Supports RS232 and RS486 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 bacnet devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports BACnet and IP input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'GW-2493M',
#   'full_description': 'BACnet/IP Server to Modbus TCP Client Gateway',
#   'specs': {'Short Description': 'BACnet/IP Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports Modbus TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 bacnet devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports BACnet and IP input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7590',
#   'full_description': 'RS-232/422/485 to M-Bus converter',
#   'specs': {'Short Description': 'M-Bus Converter',
#    'Serial Port': 'Supports RS232, RS422, and RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 100 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports M-Bus input protocol',
#    'Output Protocol': 'Supports RS232, RS485, and RS422 output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'GW-7828',
#   'full_description': 'Modbus RTU slave to M-Bus master gateway',
#   'specs': {'Short Description': 'M-Bus Gateway',
#    'Serial Port': 'Supports RS232, RS422, and RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 100 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports M-Bus input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'GW-7838-M',
#   'full_description': 'Modbus TCP server to M-Bus master gateway',
#   'specs': {'Short Description': 'M-Bus Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 100 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports M-Bus input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'DNP-211',
#   'full_description': 'DNP3 Master to Modbus TCP Server Gateway',
#   'specs': {'Short Description': 'DNP3 Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 16 clients',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports DNP3 input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'IEC850-211-S',
#   'full_description': 'Modbus TCP to IEC-61850 Gateway',
#   'specs': {'Short Description': 'IEC-61850 Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 561850 5 iec61850 clients',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports IEC61850 input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'M-7017-G',
#   'full_description': '8-ch AI Module using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Analog Input Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Voltage and Current Input input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'M-7018-G',
#   'full_description': '8-ch Thermocouple Input Module using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Thermocouple Input Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Thermocouple Input input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'M-7019R-G',
#   'full_description': '8-ch Universal AI Module with High Voltage Protection, using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Analog Input Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Thermocouple, Cuurent, and Voltage Input input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'M-7015P-G',
#   'full_description': '6-ch RTD Input Module with 3-wire Lead Resistance Elimination using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'RTD Input Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 6 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RTD Input input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7016D-G',
#   'full_description': '2-ch 4-wire Strain Gauge Input Module with LED Display using DCON Protocol (Gray Cover)',
#   'specs': {'Short Description': 'Strain Gauge Input Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 2 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Strain Gauge input protocol',
#    'Output Protocol': 'Supports DCON output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'M-7028D-G',
#   'full_description': '8-ch 12-bit AO Module with LED Display, using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Analog Output Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Voltage and Current input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'M-7026-G',
#   'full_description': '6-ch AI, 2-ch AO, 3-ch DI and 3-ch DO Module using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Multifunction I/O Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'No channel information available',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Analog and Digital input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'M-7051D-G',
#   'full_description': '16-ch Isolated (Dry, Wet) DI Module with LED Display, using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Digital Input Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 16 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Digital Input input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'M-7045D-G',
#   'full_description': '16-ch Isolated (Source, PNP, 10~40 VDC) DO Module with LED Display, using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Digital Output Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 16 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Digital Output input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'M-7055D-G',
#   'full_description': '8-ch Isolated (Dry, Wet) DI and 8-ch Isolated (Source, PNP, 10~40 VDC) DO Module with LED Display, using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Digital I/O Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 88 8 & 8s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Digital Input & Output input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'M-7061D-G',
#   'full_description': '12-ch Power Relay Module with LED Display, using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Power Relay Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 12 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports 12 Ch Power Relay input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'M-7069D-G',
#   'full_description': '8-ch Power Relay (4x Form A and 4x Form C) Module with LED Display, using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Power Relay Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Power Relay (FORM A & FORM C) input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'tM-AD5',
#   'full_description': '5-channel Isolation Analog Input Module with High Voltage Protection',
#   'specs': {'Short Description': 'Analog Input Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 5 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Voltage input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'tM-AD5C',
#   'full_description': '5-channel Isolation Current Input Module',
#   'specs': {'Short Description': 'Analog Current Input Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 5 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Current input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'tM-P4C4',
#   'full_description': '4-channel Isolation DI (Wet) and 4-channel Isolation DO (Sink, NPN) Module',
#   'specs': {'Short Description': 'Digital I/O Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 44 4 & 4s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Digital Input and Output input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'tDS-715',
#   'full_description': 'Tiny (1x RS-422/485) Serial-to-Ethernet Device Server with PoE (RoHS) Includes DC-jack to 2-wire power cable, 0',
#   'specs': {'Short Description': 'Serial Device Server',
#    'Serial Port': 'Supports RS232, RS422, and RS485 serial port',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS232, RS422, and RS485 input protocol',
#    'Output Protocol': 'Supports Ethernet TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'DS-2235i',
#   'full_description': 'Serial-to-Ethernet Device Server with 2-port Ethernet Switch and 3-port Isolated RS-422/485',
#   'specs': {'Short Description': 'Serial Device Server',
#    'Serial Port': 'Supports RS422 and 485 serial port',
#    'Ethernet': 'Supports 2x TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 3 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS422 and RS485 input protocol',
#    'Output Protocol': 'Supports 2X Ethernet TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'PDS-755',
#   'full_description': 'Programmable (1x RS-232 and 4x RS-485) Serial-to-Ethernet Device Server',
#   'specs': {'Short Description': 'Serial Device Server',
#    'Serial Port': 'Supports RS232 and 485 serial port',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 14 1 & 4s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS232 and RS485 input protocol',
#    'Output Protocol': 'Supports Ethernet TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'MSM-508',
#   'full_description': '8-port Layer 2 Managed Switch with metal casing (RoHS) Includes CA-090510 Console Cable and 4SIX1K0000003 Wall mount',
#   'specs': {'Short Description': 'Managed Switch',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'nan',
#    'Output Protocol': 'nan',
#    'Cloud Connectivity': 'No cloud connectivity',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'MSM-508FCS-T',
#   'full_description': '8-port Industrial Ethernet Layer 2 Managed Switch with 2-Fiber Port (Single-mode, SC Connector)',
#   'specs': {'Short Description': 'Managed Switch with fiber',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports 8x Ethernet ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 82 8 & 2s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Ethernet + Fiber input protocol',
#    'Output Protocol': 'nan',
#    'Cloud Connectivity': 'No cloud connectivity',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'MDC-714',
#   'full_description': 'Modbus Data Concentrator with 1 x Ethernet and 1 x RS-232, 4 x RS-485',
#   'specs': {'Short Description': 'Modbus Data Concentrator',
#    'Serial Port': 'Supports RS232 and RS485 serial port',
#    'Ethernet': 'Supports Modbus TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 14 1 & 4s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS232 and RS485 input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'No cloud connectivity',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'MDCL-705i',
#   'full_description': 'Modbus Data Concentrator with Ethernet, RS-485 Serial Ports and Data Logger, includes one 32 GB microSD card',
#   'specs': {'Short Description': 'Modbus Data Concentrator',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'Supports Modbus TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 5 s',
#    'Memory': 'Memory: 32gb',
#    'Input Protocol': 'Supports MODBUS RTU input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'Includes MicroSD slot',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'MDC-211-WF',
#   'full_description': 'Wi-Fi Modbus Data Concentrator with 1 x Ethernet, 1 x RS-232 and 1 x RS-485',
#   'specs': {'Short Description': 'Modbus Data Concentrator',
#    'Serial Port': 'Supports RS232 and RS485 serial port',
#    'Ethernet': 'Supports Modbus TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Modbus RTU and TCP IP input protocol',
#    'Output Protocol': 'Supports Wi-Fi output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NS-200AFCS-T',
#   'full_description': 'Industrial 10/100 Base-T to 100 Base-FX Media Converter; 1 single mode, SC connector',
#   'specs': {'Short Description': 'Media Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports TCP and IP input protocol',
#    'Output Protocol': 'Supports Fiber output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7561U',
#   'full_description': 'High-speed USB to Isolated RS-232/422/485 Converter with CA-USB18 Cable',
#   'specs': {'Short Description': 'USB To Serial Converter',
#    'Serial Port': 'Supports RS232, 422, and 485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS232, RS422, and RS485 input protocol',
#    'Output Protocol': 'Supports USB output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7520A',
#   'full_description': 'Isolated RS-232 to RS-422/485 Converter',
#   'specs': {'Short Description': 'Serial Converter',
#    'Serial Port': 'Supports RS232, 422, and 486 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS232 input protocol',
#    'Output Protocol': 'Supports RS422 and 485 output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7551',
#   'full_description': 'Isolated RS-232 to RS-232 Repeater',
#   'specs': {'Short Description': 'RS232 Repeater',
#    'Serial Port': 'Supports RS232 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS233 input protocol',
#    'Output Protocol': 'Supports RS232 output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'I-7514U',
#   'full_description': 'Isolated 4-channel RS-485 Repeater/Hub/Splitter',
#   'specs': {'Short Description': 'RS485 Hub',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 4 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS485 input protocol',
#    'Output Protocol': 'nan',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'tSH-735',
#   'full_description': 'Tiny (3x RS-485) Serial Port Sharer with PoE (RoHS) Includes CA-002 Cable',
#   'specs': {'Short Description': 'Sharer / Splitter',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 3 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS485 input protocol',
#    'Output Protocol': 'nan',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'USB 2514',
#   'full_description': 'USB to 4-port RS-232 Converter',
#   'specs': {'Short Description': 'USB To RS232 Converter',
#    'Serial Port': 'Supports RS232 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 4 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS232 input protocol',
#    'Output Protocol': 'Supports USB output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'tGW-718',
#   'full_description': 'Tiny Modbus TCP to RTU/ASCII Gateway with PoE and 1-port RS-232/422/485',
#   'specs': {'Short Description': 'Modbus Gateway',
#    'Serial Port': 'Supports RS232, 422, and 486 serial port',
#    'Ethernet': 'Supports Modbus TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Modbus RTU input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'ZT-2017',
#   'full_description': 'ZigBee Wireless 8-ch Analog Input Module with High Voltage Protection (ZigBee Router)',
#   'specs': {'Short Description': 'Analog Input Module with ZigBee',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Voltage & Current input protocol',
#    'Output Protocol': 'Supports ZigBee output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'ZT-2055',
#   'full_description': 'ZigBee Wireless 8-ch Isolated DI and 8-ch Isolated DO Module (ZigBee Router)',
#   'specs': {'Short Description': 'ZigBee Digital I/O  Module',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Digital I and O Module input protocol',
#    'Output Protocol': 'Supports ZigBee output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'ZT-2026',
#   'full_description': 'ZigBee Wireless 4-ch Voltage Input, 2-ch Voltage Output, 2-ch DI and 2-ch DO Module (ZigBee Router)',
#   'specs': {'Short Description': 'ZigBee Multifunction Module',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 2 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Voltage & Digital Input and Output input protocol',
#    'Output Protocol': 'Supports ZigBee output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'ZT-2570',
#   'full_description': 'Ethernet/RS-232/RS-485 to ZigBee Converter (ZigBee Coordinator)',
#   'specs': {'Short Description': 'ZigBee Converter',
#    'Serial Port': 'Supports RS232, RS485, and  serial port',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS232 and RS485 input protocol',
#    'Output Protocol': 'Supports ZigBee output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'PMC-5231M-4GE',
#   'full_description': 'Industrial IoT Power Meter Concentrator (Support 4G communication',
#   'specs': {'Short Description': 'Power Concentrator Module',
#    'Serial Port': 'Supports RS232 and 485 serial port',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 16 s',
#    'Memory': 'Memory: 32gb',
#    'Input Protocol': 'Supports Modbus TCP and RTU input protocol',
#    'Output Protocol': 'Supports SNMP & SNMP Trap, MQTT, and DDNS output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports a single 4G SIM card',
#    'Micro SD': 'Includes 32GB MicroSD card',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'WISE-5231M-4GE',
#   'full_description': 'IIoT Edge Controller (Metal Case) (Support 4G Communication',
#   'specs': {'Short Description': 'IOT Gateway',
#    'Serial Port': 'Supports RS232 and 486 serial port',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 16 s',
#    'Memory': 'Memory: 32gb',
#    'Input Protocol': 'Supports Modbus TCP and RTU input protocol',
#    'Output Protocol': 'Supports SNMP & SNMP Trap, FTP, MQTT, and CGI Command DDNS output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports a single 4G SIM card',
#    'Micro SD': 'Includes 32GB MicroSD card',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'SG-3071',
#   'full_description': 'DC Voltage Input Signal Conditioner',
#   'specs': {'Short Description': 'Signal Conditiner Module',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports 0-5VDC and 0-10VDC input protocol',
#    'Output Protocol': 'Supports 0-5VDC, 0-10VDC OR 0-20mA, and 4-20mA output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'SG-3081-G',
#   'full_description': 'DC Current Input Signal Conditioner',
#   'specs': {'Short Description': 'Signal Conditiner Module',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports 0-20mA and 4-20mA input protocol',
#    'Output Protocol': 'Supports 0-5VDC, 0-10VDC OR 0-20mA, and 4-20mA output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'ET-7017',
#   'full_description': 'Ethernet I/O Module with 8-ch AI, 4-ch DO',
#   'specs': {'Short Description': 'Analog input to Modbus TCP/IP',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Analog Input (150mV, 500mV, 1V, 5V, 10V, 20mA, 0-20mA, and 4-20mA input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'ET-7026',
#   'full_description': 'Ethernet I/O Module with 6-ch AI, 2-ch AO, 2-ch DI, 2-ch DO',
#   'specs': {'Short Description': 'Multifunction Input To Modbus TCP/IP',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Analog Input 500mV, 1V, 5V, 10V, 20mA, 0-20mA, 4-20mA, Digigital I, and O input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
# ...
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Tempreture & Humidity input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'DL-100S-E-W',
#   'full_description': 'IP66 Remote Temperature and Humidity Data Logger with LCD Display, Using Modbus TCP and MQTT Protocols',
#   'specs': {'Short Description': 'Tempreture and Humidity Data Logger With MQTT Protocol and TCP/IP',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Tempreture & Humidity input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP & MQTT output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'DL-1023',
#   'full_description': 'Remote PM1/2',
#   'specs': {'Short Description': 'Industrial Gases Data Logger',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Tempreture & Humidity PM1, 2',
#    'Output Protocol': 'Supports Modbus RTU & TCP and IP & MQTT output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'R2010-4L',
#   'full_description': 'Industrial Cellular Gateway 2 ETH+1RS232/RS485+ 1 DI + 1DO',
#   'specs': {'Short Description': 'Industrial Cellular Gateway',
#    'Serial Port': 'Supports RS232 and 485 serial port',
#    'Ethernet': 'Supports 2 x Ethernet ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'No channel information available',
#    'Memory': 'Memory: 16mb',
#    'Input Protocol': 'Supports Modbus RTU and TCP input protocol',
#    'Output Protocol': 'Supports IPSec, mqtt, dnp3, iec104, and L2TP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports dual 4G SIM cards',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'R3000-L4L',
#   'full_description': 'Industrial Dual SIM Cellular VPN Router 1 Eth + 1 RS-232 + 1 RS-485 + 1 USB Host',
#   'specs': {'Short Description': 'Dual SIM Cellular VPN Router',
#    'Serial Port': 'Supports RS232 and 485 serial port',
#    'Ethernet': 'Supports 1 x Ethernet ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory: 16mb',
#    'Input Protocol': 'Supports Modbus RTU and TCP input protocol',
#    'Output Protocol': 'Supports IPSec, mqtt, dnp3, iec104, and L2TP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports dual 4G SIM cards',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'R5020-Lite',
#   'full_description': 'High Speed Smart 5G Router 2 Eth + 1 RS232 /RS485 + High-speed dual-band Wi-Fi',
#   'specs': {'Short Description': 'Industrial 5G Router',
#    'Serial Port': 'Supports RS232 and 485 serial port',
#    'Ethernet': 'Supports 2 x Ethernet ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory: 16mb',
#    'Input Protocol': 'Supports Modbus RTU and TCP input protocol',
#    'Output Protocol': 'Supports IPSec, mqtt, dnp3, iec104, and L2TP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports dual 5G SIM cards',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NT-RTU-23',
#   'full_description': 'Industrial Cellular Modem 2 ETH+ 1 RS232/RS485 + 1 DI + 1 DO',
#   'specs': {'Short Description': 'VPN Router',
#    'Serial Port': 'Supports RS232 and 485 serial port',
#    'Ethernet': 'Supports 2 x Ethernet ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 10 s',
#    'Memory': 'Memory: 16mb',
#    'Input Protocol': 'Supports Modbus RTU and TCP input protocol',
#    'Output Protocol': 'Supports IPSec, mqtt, dnp3, iec104, and L2TP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports dual 4G SIM cards',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NT-RTU-24',
#   'full_description': 'Embedded 4G Router 2 Ethernet + Wi-Fi + 1 SIM + 1 RS232/RS485',
#   'specs': {'Short Description': 'Industreial 4G Router',
#    'Serial Port': 'Supports RS232 and 486 serial port',
#    'Ethernet': 'Supports 2 x Ethernet ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 10 s',
#    'Memory': 'Memory: 16mb',
#    'Input Protocol': 'Supports Modbus RTU and TCP input protocol',
#    'Output Protocol': 'Supports IPSec, mqtt, dnp3, iec104, and L2TP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports a single 4G SIM card',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NT-201-S-U',
#   'full_description': 'LoRa To RS232/422/485 Converter',
#   'specs': {'Short Description': 'LoRa To Serial Converter',
#    'Serial Port': 'Supports RS232 and 487 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 10 s',
#    'Memory': 'Memory: 16kb',
#    'Input Protocol': 'Supports Modbus RTU input protocol',
#    'Output Protocol': 'Supports Lora output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NT-201-DIO-U',
#   'full_description': 'LoRa To 4 Digital Input & 3 Digital Output Module',
#   'specs': {'Short Description': 'LoRa Digital I/O Module',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory: 128kb',
#    'Input Protocol': 'Supports Digital Input & Output input protocol',
#    'Output Protocol': 'Supports Lora output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NTS-201-AI',
#   'full_description': 'Analog Input To LoRaWAN Converter',
#   'specs': {'Short Description': 'LoRaWAN Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory: 16kb',
#    'Input Protocol': 'Supports Analog Input(0-10VDC and 4-20mA) input protocol',
#    'Output Protocol': 'Supports LoraWAN output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NTS-201-AO',
#   'full_description': 'Analog Output To LoRa Converter',
#   'specs': {'Short Description': 'LoRawan Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory: 380kb',
#    'Input Protocol': 'Supports Analog Output input protocol',
#    'Output Protocol': 'Supports LoraWAN output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NTS-201-DIO',
#   'full_description': '2 DI & 2 DO To LoRaWAN Module',
#   'specs': {'Short Description': 'LoRaWAN Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory: 380kb',
#    'Input Protocol': 'Supports Digital Input & Output input protocol',
#    'Output Protocol': 'Supports LoraWAN output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NT-201-E-MODBUS',
#   'full_description': 'Modbus Ethernet To LoRa Converter',
#   'specs': {'Short Description': 'LoRa Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory: 128kb',
#    'Input Protocol': 'Supports Modbus TCP and IP input protocol',
#    'Output Protocol': 'Supports LoRa output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'USB232',
#   'full_description': 'RS232 To USB onverter',
#   'specs': {'Short Description': 'RS232 Converter',
#    'Serial Port': 'Supports RS232 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS232 input protocol',
#    'Output Protocol': 'Supports USB output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'USB485',
#   'full_description': 'RS485 To USB onverter',
#   'specs': {'Short Description': 'RS485 Converter',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS485 input protocol',
#    'Output Protocol': 'Supports USB output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NT-832-AH-E',
#   'full_description': 'Ethernet To Wi-Fi Converter',
#   'specs': {'Short Description': 'Wi-Fi Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports TCP and IP input protocol',
#    'Output Protocol': 'Supports Wi-Fi output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NT-832-AH-485',
#   'full_description': 'RS485 To Wi-Fi',
#   'specs': {'Short Description': 'Wi-Fi Converter',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS485 input protocol',
#    'Output Protocol': 'Supports Wi-Fi output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NT-201-G-WAN+4G',
#   'full_description': 'Ethernet To LoRaWAN Gateway',
#   'specs': {'Short Description': 'LoRaWAN Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory: 32 mb',
#    'Input Protocol': 'Supports TCP and IP input protocol',
#    'Output Protocol': 'Supports UDP, MQTT, DHCP, and Static IP and DHCP Server output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports a single 4G SIM card',
#    'Micro SD': 'Includes MicroSD slot',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NT-632-PI-CM4',
#   'full_description': 'Programmable Gateway',
#   'specs': {'Short Description': 'Risbery PI Gateway',
#    'Serial Port': 'Supports RS232, 485, and 422 serial port',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory: 8/16/32gb',
#    'Input Protocol': 'Supports Modbus RTU and TCP input protocol',
#    'Output Protocol': 'Supports MQTT output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports a single 4G SIM card',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'tNS-200IN',
#   'full_description': '10/100 Base-TX, PoE injector for 1 PoE port',
#   'specs': {'Short Description': 'POE Splitter',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports TCP and IP input protocol',
#    'Output Protocol': 'Supports POE output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NT-4421',
#   'full_description': '4DI, 2DO, 4AI, With RS485',
#   'specs': {'Short Description': 'IOT Gateway',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Modbus RTU input protocol',
#    'Output Protocol': 'Supports MQTT output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports a single 4G SIM card',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NT-S1-4G',
#   'full_description': 'RS485 To Server',
#   'specs': {'Short Description': '4G IOT Gateway',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 6 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Modbus RTU input protocol',
#    'Output Protocol': 'Supports MQTT output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports a single 4G SIM card',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NT-T20-4G',
#   'full_description': 'Tempreture and Humidity data Logger',
#   'specs': {'Short Description': 'Tempreture Data Logger',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory: yes',
#    'Input Protocol': 'Supports Tempreture & Humidity input protocol',
#    'Output Protocol': 'Supports MQTT output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports a single 4G SIM card',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}},
#  {'model_no': 'NT-MB307B',
#   'full_description': 'Analog and Digital I/O To Modbus RTU or TCP/IP Converter',
#   'specs': {'Short Description': 'Multifunction I/O To Modbus RTU/TCP Converter',
#    'Serial Port': 'Supports RS485 and 232 serial port',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Analog and Digital I and O Module input protocol',
#    'Output Protocol': 'Supports Modbus RTU and TCP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'}}]

# %%
def create_embedding_text(item):
    parts = [
        f"Model No: {item['model_no']}",
        # f"Short Description: {item['short_description']}",
        f"Full Description: {item['full_description']}",
        specs_to_string(item["specs"])  # Cleaned specs as one string
    ]
    return ". ".join(parts)

def normalize_text(text):
    text = text.lower()
    text = re.sub(r'\s+', ' ', text)              # Collapse multiple spaces
    text = re.sub(r'\s([:;,.])', r'\1', text)      # Remove space before punctuation
    text = text.strip()
    return text

# Add new field for embedding
for item in products:
    item["embedding_text"] = create_embedding_text(item)
    item["embedding_text"] = item["embedding_text"].lower()
    item["embedding_text"] = normalize_text(item["embedding_text"])

products
# Out:
# [{'model_no': 'I-7547',
#   'full_description': 'Ethernet(TCP/IP) to HART Converter',
#   'specs': {'Short Description': 'HART Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCI and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 HART devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports HART input protocol',
#    'Output Protocol': 'Supports Ethernet TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: i-7547. full description: ethernet(tcp/ip) to hart converter. short description: hart converter. serial port: not available. ethernet: supports tci and ip ethernet port. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports ethernet tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'I-7567',
#   'full_description': 'USB to HART converter',
#   'specs': {'Short Description': 'HART Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 HART devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports HART input protocol',
#    'Output Protocol': 'Supports USB output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: i-7567. full description: usb to hart converter. short description: hart converter. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports usb output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'I-7570',
#   'full_description': 'Serial to HART converter',
#   'specs': {'Short Description': 'HART Converter',
#    'Serial Port': 'Supports RS232, RS422, and RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 HART devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports HART input protocol',
#    'Output Protocol': 'Supports RS232, RS485, and RS422 output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: i-7570. full description: serial to hart converter. short description: hart converter. serial port: supports rs232, rs422, and rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports rs232, rs485, and rs422 output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'HRT-227CS',
#   'full_description': 'HART to Single Mode Fiber Converter',
#   'specs': {'Short Description': 'HART Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 HART devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports HART input protocol',
#    'Output Protocol': 'Supports FIBER output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: hrt-227cs. full description: hart to single mode fiber converter. short description: hart converter. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports fiber output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'HRT-710',
#   'full_description': 'Modbus/RTU & ASCII to HART gateway',
#   'specs': {'Short Description': 'HART Gateway',
#    'Serial Port': 'Supports RS232 and RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 HART devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports HART input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: hrt-710. full description: modbus/rtu & ascii to hart gateway. short description: hart gateway. serial port: supports rs232 and rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'HRT-711',
#   'full_description': 'Modbus TCP/UDP to HART Gateway',
#   'specs': {'Short Description': 'HART Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 HART devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports HART input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: hrt-711. full description: modbus tcp/udp to hart gateway. short description: hart gateway. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'I-7550-B',
#   'full_description': 'PROFIBUS to RS-232/422/485 Converter(Plastic Case)',
#   'specs': {'Short Description': 'Profibus Converter',
#    'Serial Port': 'Supports RS232, RS422, and RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profibus DP input protocol',
#    'Output Protocol': 'Supports RS232, RS485, and RS422 output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: i-7550-b. full description: profibus to rs-232/422/485 converter(plastic case). short description: profibus converter. serial port: supports rs232, rs422, and rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports rs232, rs485, and rs422 output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'I-7550E',
#   'full_description': 'PROFIBUS to Ethernet Converter(Plastic Case)',
#   'specs': {'Short Description': 'Profibus Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 6 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profibus DP input protocol',
#    'Output Protocol': 'Supports TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: i-7550e. full description: profibus to ethernet converter(plastic case). short description: profibus converter. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 6 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'PROFI-2510',
#   'full_description': 'Isolated PROFIBUS Repeater',
#   'specs': {'Short Description': 'Profibus Repeater',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 15 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profibus DP input protocol',
#    'Output Protocol': 'Supports Profibus DP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: profi-2510. full description: isolated profibus repeater. short description: profibus repeater. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 15 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports profibus dp output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'PROFI-2541-SC',
#   'full_description': 'PROFIBUS DP to Multi-mode Fiber Converter (SC-Type)',
#   'specs': {'Short Description': 'Profibus Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 15 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profibus DP input protocol',
#    'Output Protocol': 'Supports FIBER output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: profi-2541-sc. full description: profibus dp to multi-mode fiber converter (sc-type). short description: profibus converter. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 15 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports fiber output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'GW-7552-B',
#   'full_description': 'PROFIBUS to Modbus Gateway (Plastic Case)',
#   'specs': {'Short Description': 'Profibus Gateway',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profibus DP input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: gw-7552-b. full description: profibus to modbus gateway (plastic case). short description: profibus gateway. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'GW-7553-B',
#   'full_description': 'PROFIBUS to Modbus TCP Gateway (Plastic Case)',
#   'specs': {'Short Description': 'Profibus Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profibus DP input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: gw-7553-b. full description: profibus to modbus tcp gateway (plastic case). short description: profibus gateway. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 8 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'GW-7553-CPM',
#   'full_description': 'PROFIBUS to CANopen Gateway (Plastic Case)',
#   'specs': {'Short Description': 'CANopen Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profibus DP input protocol',
#    'Output Protocol': 'Supports CANOpen output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: gw-7553-cpm. full description: profibus to canopen gateway (plastic case). short description: canopen gateway. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports canopen output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'I-7580',
#   'full_description': 'PROFINET to RS-232/422/485 Converter',
#   'specs': {'Short Description': 'Profinet Converter',
#    'Serial Port': 'Supports RS232, RS485, and RS422 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profinet input protocol',
#    'Output Protocol': 'Supports RS232, RS485, and RS422 output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: i-7580. full description: profinet to rs-232/422/485 converter. short description: profinet converter. serial port: supports rs232, rs485, and rs422 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 slave devices. memory: not available. input protocol: supports profinet input protocol. output protocol: supports rs232, rs485, and rs422 output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'GW-7662',
#   'full_description': 'PROFINET to Modbus RTU/ASCII Gateway',
#   'specs': {'Short Description': 'Profinet Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profinet input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: gw-7662. full description: profinet to modbus rtu/ascii gateway. short description: profinet gateway. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 slave devices. memory: not available. input protocol: supports profinet input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'GW-7663',
#   'full_description': 'PROFINET to Modbus TCP Gateway',
#   'specs': {'Short Description': 'Profinet Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Profinet input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: gw-7663. full description: profinet to modbus tcp gateway. short description: profinet gateway. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 8 slave devices. memory: not available. input protocol: supports profinet input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'I-2533CS',
#   'full_description': 'CAN to Single-mode Fiber Bridge; 1 (30 km) single-mode, SC connector',
#   'specs': {'Short Description': 'CAN Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1 CAN device',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANBus input protocol',
#    'Output Protocol': 'Supports FIBER output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: i-2533cs. full description: can to single-mode fiber bridge; 1 (30 km) single-mode, sc connector. short description: can converter. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 1 can device. memory: not available. input protocol: supports canbus input protocol. output protocol: supports fiber output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'I-7531-FD-G',
#   'full_description': 'Two-channel Isolated CAN / CAN FD Signal Repeater',
#   'specs': {'Short Description': 'CAN Repeater',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 2 CAN devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANBus input protocol',
#    'Output Protocol': 'Supports CANBus output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: i-7531-fd-g. full description: two-channel isolated can / can fd signal repeater. short description: can repeater. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 2 can devices. memory: not available. input protocol: supports canbus input protocol. output protocol: supports canbus output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'I-7530A-G',
#   'full_description': 'Intelligent RS-232/485/422 to CAN converter',
#   'specs': {'Short Description': 'CAN Converter',
#    'Serial Port': 'Supports RS232, RS422, and RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 CAN devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANBus input protocol',
#    'Output Protocol': 'Supports RS232, RS485, and RS422 output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: i-7530a-g. full description: intelligent rs-232/485/422 to can converter. short description: can converter. serial port: supports rs232, rs422, and rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 can devices. memory: not available. input protocol: supports canbus input protocol. output protocol: supports rs232, rs485, and rs422 output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'I-7530A-MR-FD',
#   'full_description': 'Modbus RTU to CAN Converter',
#   'specs': {'Short Description': 'CAN Gateway',
#    'Serial Port': 'Supports RS232, RS422, and RS486 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 CAN devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANBus input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: i-7530a-mr-fd. full description: modbus rtu to can converter. short description: can gateway. serial port: supports rs232, rs422, and rs486 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 can devices. memory: not available. input protocol: supports canbus input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'I-7540D-MTCP-G',
#   'full_description': 'CAN to Ethernet / Modbus TCP / Modbus RTU Converter (Plastic Case)',
#   'specs': {'Short Description': 'CAN Gateway',
#    'Serial Port': 'Supports RS232 and RS485 serial port',
#    'Ethernet': 'Supports Modbus TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 CAN devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANBus input protocol',
#    'Output Protocol': 'Supports Modbus RTU and TCPIP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: i-7540d-mtcp-g. full description: can to ethernet / modbus tcp / modbus rtu converter (plastic case). short description: can gateway. serial port: supports rs232 and rs485 serial port. ethernet: supports modbus tcp and ip ethernet port. usb: no usb port available. channels: supports 8 can devices. memory: not available. input protocol: supports canbus input protocol. output protocol: supports modbus rtu and tcpip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'I-7565-H2-G',
#   'full_description': 'High Performance Intelligent USB to 2-port CAN bus converter (Plastic Case)',
#   'specs': {'Short Description': 'CAN Bus Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 2 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANBus input protocol',
#    'Output Protocol': 'Supports USB output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: i-7565-h2-g. full description: high performance intelligent usb to 2-port can bus converter (plastic case). short description: can bus gateway. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 2 s. memory: not available. input protocol: supports canbus input protocol. output protocol: supports usb output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'ECAN-240-FD',
#   'full_description': 'Modbus TCP to 2-port CAN FD Gateway',
#   'specs': {'Short Description': 'CAN Bus Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports Modbus TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 2 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANBus input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: ecan-240-fd. full description: modbus tcp to 2-port can fd gateway. short description: can bus gateway. serial port: not available. ethernet: supports modbus tcp and ip ethernet port. usb: no usb port available. channels: supports 2 s. memory: not available. input protocol: supports canbus input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'GW-7433D',
#   'full_description': 'Modbus TCP server/RTU slave to CANopen Master Gateway',
#   'specs': {'Short Description': 'CANopen Gateway',
#    'Serial Port': 'Supports RS232 and RS485 serial port',
#    'Ethernet': 'Supports Modbus TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 CAN devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports CANOpen input protocol',
#    'Output Protocol': 'Supports Modbus RTU and TCPIP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: gw-7433d. full description: modbus tcp server/rtu slave to canopen master gateway. short description: canopen gateway. serial port: supports rs232 and rs485 serial port. ethernet: supports modbus tcp and ip ethernet port. usb: no usb port available. channels: supports 8 can devices. memory: not available. input protocol: supports canopen input protocol. output protocol: supports modbus rtu and tcpip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'GW-2492M',
#   'full_description': 'BACnet/IP Server to Modbus RTU Master Gateway',
#   'specs': {'Short Description': 'BACnet/IP Gateway',
#    'Serial Port': 'Supports RS232 and RS486 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 bacnet devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports BACnet and IP input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: gw-2492m. full description: bacnet/ip server to modbus rtu master gateway. short description: bacnet/ip gateway. serial port: supports rs232 and rs486 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 bacnet devices. memory: not available. input protocol: supports bacnet and ip input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'GW-2493M',
#   'full_description': 'BACnet/IP Server to Modbus TCP Client Gateway',
#   'specs': {'Short Description': 'BACnet/IP Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports Modbus TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 bacnet devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports BACnet and IP input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: gw-2493m. full description: bacnet/ip server to modbus tcp client gateway. short description: bacnet/ip gateway. serial port: not available. ethernet: supports modbus tcp and ip ethernet port. usb: no usb port available. channels: supports 8 bacnet devices. memory: not available. input protocol: supports bacnet and ip input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'I-7590',
#   'full_description': 'RS-232/422/485 to M-Bus converter',
#   'specs': {'Short Description': 'M-Bus Converter',
#    'Serial Port': 'Supports RS232, RS422, and RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 100 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports M-Bus input protocol',
#    'Output Protocol': 'Supports RS232, RS485, and RS422 output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: i-7590. full description: rs-232/422/485 to m-bus converter. short description: m-bus converter. serial port: supports rs232, rs422, and rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 100 slave devices. memory: not available. input protocol: supports m-bus input protocol. output protocol: supports rs232, rs485, and rs422 output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'GW-7828',
#   'full_description': 'Modbus RTU slave to M-Bus master gateway',
#   'specs': {'Short Description': 'M-Bus Gateway',
#    'Serial Port': 'Supports RS232, RS422, and RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 100 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports M-Bus input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: gw-7828. full description: modbus rtu slave to m-bus master gateway. short description: m-bus gateway. serial port: supports rs232, rs422, and rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 100 slave devices. memory: not available. input protocol: supports m-bus input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'GW-7838-M',
#   'full_description': 'Modbus TCP server to M-Bus master gateway',
#   'specs': {'Short Description': 'M-Bus Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 100 slave devices',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports M-Bus input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: gw-7838-m. full description: modbus tcp server to m-bus master gateway. short description: m-bus gateway. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 100 slave devices. memory: not available. input protocol: supports m-bus input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'DNP-211',
#   'full_description': 'DNP3 Master to Modbus TCP Server Gateway',
#   'specs': {'Short Description': 'DNP3 Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 16 clients',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports DNP3 input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: dnp-211. full description: dnp3 master to modbus tcp server gateway. short description: dnp3 gateway. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 16 clients. memory: not available. input protocol: supports dnp3 input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'IEC850-211-S',
#   'full_description': 'Modbus TCP to IEC-61850 Gateway',
#   'specs': {'Short Description': 'IEC-61850 Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 561850 5 iec61850 clients',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports IEC61850 input protocol',
#    'Output Protocol': 'Supports Modbus TCP and IP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: iec850-211-s. full description: modbus tcp to iec-61850 gateway. short description: iec-61850 gateway. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 561850 5 iec61850 clients. memory: not available. input protocol: supports iec61850 input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'M-7017-G',
#   'full_description': '8-ch AI Module using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Analog Input Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Voltage and Current Input input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: m-7017-g. full description: 8-ch ai module using dcon and modbus protocols (gray cover). short description: analog input module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: not available. input protocol: supports voltage and current input input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'M-7018-G',
#   'full_description': '8-ch Thermocouple Input Module using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Thermocouple Input Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Thermocouple Input input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: m-7018-g. full description: 8-ch thermocouple input module using dcon and modbus protocols (gray cover). short description: thermocouple input module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: not available. input protocol: supports thermocouple input input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'M-7019R-G',
#   'full_description': '8-ch Universal AI Module with High Voltage Protection, using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Analog Input Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Thermocouple, Cuurent, and Voltage Input input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: m-7019r-g. full description: 8-ch universal ai module with high voltage protection, using dcon and modbus protocols (gray cover). short description: analog input module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: not available. input protocol: supports thermocouple, cuurent, and voltage input input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'M-7015P-G',
#   'full_description': '6-ch RTD Input Module with 3-wire Lead Resistance Elimination using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'RTD Input Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 6 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RTD Input input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: m-7015p-g. full description: 6-ch rtd input module with 3-wire lead resistance elimination using dcon and modbus protocols (gray cover). short description: rtd input module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 6 s. memory: not available. input protocol: supports rtd input input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'I-7016D-G',
#   'full_description': '2-ch 4-wire Strain Gauge Input Module with LED Display using DCON Protocol (Gray Cover)',
#   'specs': {'Short Description': 'Strain Gauge Input Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 2 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Strain Gauge input protocol',
#    'Output Protocol': 'Supports DCON output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: i-7016d-g. full description: 2-ch 4-wire strain gauge input module with led display using dcon protocol (gray cover). short description: strain gauge input module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 2 s. memory: not available. input protocol: supports strain gauge input protocol. output protocol: supports dcon output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'M-7028D-G',
#   'full_description': '8-ch 12-bit AO Module with LED Display, using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Analog Output Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Voltage and Current input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: m-7028d-g. full description: 8-ch 12-bit ao module with led display, using dcon and modbus protocols (gray cover). short description: analog output module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: not available. input protocol: supports voltage and current input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'M-7026-G',
#   'full_description': '6-ch AI, 2-ch AO, 3-ch DI and 3-ch DO Module using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Multifunction I/O Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'No channel information available',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Analog and Digital input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: m-7026-g. full description: 6-ch ai, 2-ch ao, 3-ch di and 3-ch do module using dcon and modbus protocols (gray cover). short description: multifunction i/o module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: no channel information available. memory: not available. input protocol: supports analog and digital input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'M-7051D-G',
#   'full_description': '16-ch Isolated (Dry, Wet) DI Module with LED Display, using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Digital Input Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 16 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Digital Input input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: m-7051d-g. full description: 16-ch isolated (dry, wet) di module with led display, using dcon and modbus protocols (gray cover). short description: digital input module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 16 s. memory: not available. input protocol: supports digital input input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'M-7045D-G',
#   'full_description': '16-ch Isolated (Source, PNP, 10~40 VDC) DO Module with LED Display, using DCON and Modbus Protocols (Gray Cover)',
#   'specs': {'Short Description': 'Digital Output Module',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 16 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Digital Output input protocol',
#    'Output Protocol': 'Supports Modbus RTU output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
# ...
#  {'model_no': 'NTS-201-AO',
#   'full_description': 'Analog Output To LoRa Converter',
#   'specs': {'Short Description': 'LoRawan Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory: 380kb',
#    'Input Protocol': 'Supports Analog Output input protocol',
#    'Output Protocol': 'Supports LoraWAN output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: nts-201-ao. full description: analog output to lora converter. short description: lorawan converter. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: memory: 380kb. input protocol: supports analog output input protocol. output protocol: supports lorawan output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'NTS-201-DIO',
#   'full_description': '2 DI & 2 DO To LoRaWAN Module',
#   'specs': {'Short Description': 'LoRaWAN Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory: 380kb',
#    'Input Protocol': 'Supports Digital Input & Output input protocol',
#    'Output Protocol': 'Supports LoraWAN output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: nts-201-dio. full description: 2 di & 2 do to lorawan module. short description: lorawan converter. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: memory: 380kb. input protocol: supports digital input & output input protocol. output protocol: supports lorawan output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'NT-201-E-MODBUS',
#   'full_description': 'Modbus Ethernet To LoRa Converter',
#   'specs': {'Short Description': 'LoRa Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory: 128kb',
#    'Input Protocol': 'Supports Modbus TCP and IP input protocol',
#    'Output Protocol': 'Supports LoRa output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: nt-201-e-modbus. full description: modbus ethernet to lora converter. short description: lora converter. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 8 s. memory: memory: 128kb. input protocol: supports modbus tcp and ip input protocol. output protocol: supports lora output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'USB232',
#   'full_description': 'RS232 To USB onverter',
#   'specs': {'Short Description': 'RS232 Converter',
#    'Serial Port': 'Supports RS232 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS232 input protocol',
#    'Output Protocol': 'Supports USB output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: usb232. full description: rs232 to usb onverter. short description: rs232 converter. serial port: supports rs232 serial port. ethernet: not available. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports rs232 input protocol. output protocol: supports usb output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'USB485',
#   'full_description': 'RS485 To USB onverter',
#   'specs': {'Short Description': 'RS485 Converter',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS485 input protocol',
#    'Output Protocol': 'Supports USB output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: usb485. full description: rs485 to usb onverter. short description: rs485 converter. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports rs485 input protocol. output protocol: supports usb output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'NT-832-AH-E',
#   'full_description': 'Ethernet To Wi-Fi Converter',
#   'specs': {'Short Description': 'Wi-Fi Converter',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports TCP and IP input protocol',
#    'Output Protocol': 'Supports Wi-Fi output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: nt-832-ah-e. full description: ethernet to wi-fi converter. short description: wi-fi converter. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports tcp and ip input protocol. output protocol: supports wi-fi output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'NT-832-AH-485',
#   'full_description': 'RS485 To Wi-Fi',
#   'specs': {'Short Description': 'Wi-Fi Converter',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports RS485 input protocol',
#    'Output Protocol': 'Supports Wi-Fi output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: nt-832-ah-485. full description: rs485 to wi-fi. short description: wi-fi converter. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports rs485 input protocol. output protocol: supports wi-fi output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'NT-201-G-WAN+4G',
#   'full_description': 'Ethernet To LoRaWAN Gateway',
#   'specs': {'Short Description': 'LoRaWAN Gateway',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory: 32 mb',
#    'Input Protocol': 'Supports TCP and IP input protocol',
#    'Output Protocol': 'Supports UDP, MQTT, DHCP, and Static IP and DHCP Server output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports a single 4G SIM card',
#    'Micro SD': 'Includes MicroSD slot',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: nt-201-g-wan+4g. full description: ethernet to lorawan gateway. short description: lorawan gateway. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 8 s. memory: memory: 32 mb. input protocol: supports tcp and ip input protocol. output protocol: supports udp, mqtt, dhcp, and static ip and dhcp server output protocol. cloud connectivity: cloud connectivity available. sim card: supports a single 4g sim card. micro sd: includes microsd slot. wi-fi: not supported'},
#  {'model_no': 'NT-632-PI-CM4',
#   'full_description': 'Programmable Gateway',
#   'specs': {'Short Description': 'Risbery PI Gateway',
#    'Serial Port': 'Supports RS232, 485, and 422 serial port',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory: 8/16/32gb',
#    'Input Protocol': 'Supports Modbus RTU and TCP input protocol',
#    'Output Protocol': 'Supports MQTT output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports a single 4G SIM card',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: nt-632-pi-cm4. full description: programmable gateway. short description: risbery pi gateway. serial port: supports rs232, 485, and 422 serial port. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: memory: 8/16/32gb. input protocol: supports modbus rtu and tcp input protocol. output protocol: supports mqtt output protocol. cloud connectivity: cloud connectivity available. sim card: supports a single 4g sim card. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'tNS-200IN',
#   'full_description': '10/100 Base-TX, PoE injector for 1 PoE port',
#   'specs': {'Short Description': 'POE Splitter',
#    'Serial Port': 'not available',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports TCP and IP input protocol',
#    'Output Protocol': 'Supports POE output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: tns-200in. full description: 10/100 base-tx, poe injector for 1 poe port. short description: poe splitter. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports tcp and ip input protocol. output protocol: supports poe output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'NT-4421',
#   'full_description': '4DI, 2DO, 4AI, With RS485',
#   'specs': {'Short Description': 'IOT Gateway',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Modbus RTU input protocol',
#    'Output Protocol': 'Supports MQTT output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports a single 4G SIM card',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: nt-4421. full description: 4di, 2do, 4ai, with rs485. short description: iot gateway. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports modbus rtu input protocol. output protocol: supports mqtt output protocol. cloud connectivity: cloud connectivity available. sim card: supports a single 4g sim card. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'NT-S1-4G',
#   'full_description': 'RS485 To Server',
#   'specs': {'Short Description': '4G IOT Gateway',
#    'Serial Port': 'Supports RS485 serial port',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 6 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Modbus RTU input protocol',
#    'Output Protocol': 'Supports MQTT output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports a single 4G SIM card',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: nt-s1-4g. full description: rs485 to server. short description: 4g iot gateway. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 6 s. memory: not available. input protocol: supports modbus rtu input protocol. output protocol: supports mqtt output protocol. cloud connectivity: cloud connectivity available. sim card: supports a single 4g sim card. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'NT-T20-4G',
#   'full_description': 'Tempreture and Humidity data Logger',
#   'specs': {'Short Description': 'Tempreture Data Logger',
#    'Serial Port': 'not available',
#    'Ethernet': 'not available',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 1',
#    'Memory': 'Memory: yes',
#    'Input Protocol': 'Supports Tempreture & Humidity input protocol',
#    'Output Protocol': 'Supports MQTT output protocol',
#    'Cloud Connectivity': 'Cloud connectivity available',
#    'SIM Card': 'Supports a single 4G SIM card',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: nt-t20-4g. full description: tempreture and humidity data logger. short description: tempreture data logger. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 1. memory: memory: yes. input protocol: supports tempreture & humidity input protocol. output protocol: supports mqtt output protocol. cloud connectivity: cloud connectivity available. sim card: supports a single 4g sim card. micro sd: not supported. wi-fi: not supported'},
#  {'model_no': 'NT-MB307B',
#   'full_description': 'Analog and Digital I/O To Modbus RTU or TCP/IP Converter',
#   'specs': {'Short Description': 'Multifunction I/O To Modbus RTU/TCP Converter',
#    'Serial Port': 'Supports RS485 and 232 serial port',
#    'Ethernet': 'Supports TCP and IP ethernet port',
#    'USB': 'No USB port available',
#    'Channels': 'Supports 8 s',
#    'Memory': 'Memory not available',
#    'Input Protocol': 'Supports Analog and Digital I and O Module input protocol',
#    'Output Protocol': 'Supports Modbus RTU and TCP output protocol',
#    'Cloud Connectivity': 'Cloud connectivity via external modem',
#    'SIM Card': 'No SIM support available',
#    'Micro SD': 'No MicroSD support',
#    'Wi-Fi': 'No Wi-Fi support'},
#   'embedding_text': 'model no: nt-mb307b. full description: analog and digital i/o to modbus rtu or tcp/ip converter. short description: multifunction i/o to modbus rtu/tcp converter. serial port: supports rs485 and 232 serial port. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 8 s. memory: not available. input protocol: supports analog and digital i and o module input protocol. output protocol: supports modbus rtu and tcp output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'}]

# %%
docs = [item["embedding_text"] for item in products]

# %%
import os
from openai import OpenAI
from pinecone import Pinecone, ServerlessSpec

# Set your keys
os.environ["OPENAI_API_KEY"] = "YOUR_OPENAI_API_KEY_HERE"   # OpenAI key
os.environ["PINECONE_API_KEY"] = "YOUR_PINECONE_API_KEY_HERE"

# %%
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])
pc = Pinecone(api_key=os.environ["PINECONE_API_KEY"])

# %%
from pinecone import Pinecone, ServerlessSpec

pc = Pinecone(api_key="YOUR_PINECONE_API_KEY_HERE")

# %%
index_name = "model-prompter"

if not pc.has_index(index_name):
    pc.create_index_for_model(
        name=index_name,
        cloud="aws",
        region="us-east-1",
        embed={
            "model":"llama-text-embed-v2",
            "field_map":{"text": "chunk_text"}
        }
    )

# %%
# index_name = "model-prompter"

# # Create index if not exists
# if index_name not in pc.list_indexes().names():
#     pc.create_index(
#         name=index_name,
#         dimension=1536,  # for text-embedding-3-small
#         metric='euclidean',
#         spec=pc.serverless.ServerlessSpec(
#             cloud='aws',
#             region='us-east-1'
#         )
#     )

# # index = pc.Index(index_name)


# # Delete the old index
# # pc.delete_index("model-prompter")

# # pc.create_index(
# #     name="model-prompter",
# #     dimension=1536,
# #     metric="euclidean",
# #     spec=ServerlessSpec(
# #         cloud="aws",
# #         region="us-east-1"
# #     )
# # )

# %%
docs = [item["embedding_text"] for item in products]
print(docs)
# Out:
# ['model no: i-7547. full description: ethernet(tcp/ip) to hart converter. short description: hart converter. serial port: not available. ethernet: supports tci and ip ethernet port. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports ethernet tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported', 'model no: i-7567. full description: usb to hart converter. short description: hart converter. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports usb output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported', 'model no: i-7570. full description: serial to hart converter. short description: hart converter. serial port: supports rs232, rs422, and rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports rs232, rs485, and rs422 output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported', 'model no: hrt-227cs. full description: hart to single mode fiber converter. short description: hart converter. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports fiber output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported', 'model no: hrt-710. full description: modbus/rtu & ascii to hart gateway. short description: hart gateway. serial port: supports rs232 and rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported', 'model no: hrt-711. full description: modbus tcp/udp to hart gateway. short description: hart gateway. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported', 'model no: i-7550-b. full description: profibus to rs-232/422/485 converter(plastic case). short description: profibus converter. serial port: supports rs232, rs422, and rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports rs232, rs485, and rs422 output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported', 'model no: i-7550e. full description: profibus to ethernet converter(plastic case). short description: profibus converter. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 6 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: no ...

# %%
def extract_model_id(text):
    match = re.search(r"model no:\s*([a-zA-Z0-9\-_.]+)", text, re.IGNORECASE)
    return match.group(1) if match else None

# Build properly formatted documents
formatted_docs = []
for doc in docs:
    model_id = extract_model_id(doc)
    if model_id:
        formatted_docs.append({"id": model_id, "chunk_text": doc})

formatted_docs
# Out:
# [{'id': 'i-7547.',
#   'chunk_text': 'model no: i-7547. full description: ethernet(tcp/ip) to hart converter. short description: hart converter. serial port: not available. ethernet: supports tci and ip ethernet port. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports ethernet tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7567.',
#   'chunk_text': 'model no: i-7567. full description: usb to hart converter. short description: hart converter. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports usb output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7570.',
#   'chunk_text': 'model no: i-7570. full description: serial to hart converter. short description: hart converter. serial port: supports rs232, rs422, and rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports rs232, rs485, and rs422 output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'hrt-227cs.',
#   'chunk_text': 'model no: hrt-227cs. full description: hart to single mode fiber converter. short description: hart converter. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports fiber output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'hrt-710.',
#   'chunk_text': 'model no: hrt-710. full description: modbus/rtu & ascii to hart gateway. short description: hart gateway. serial port: supports rs232 and rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'hrt-711.',
#   'chunk_text': 'model no: hrt-711. full description: modbus tcp/udp to hart gateway. short description: hart gateway. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 8 hart devices. memory: not available. input protocol: supports hart input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7550-b.',
#   'chunk_text': 'model no: i-7550-b. full description: profibus to rs-232/422/485 converter(plastic case). short description: profibus converter. serial port: supports rs232, rs422, and rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports rs232, rs485, and rs422 output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7550e.',
#   'chunk_text': 'model no: i-7550e. full description: profibus to ethernet converter(plastic case). short description: profibus converter. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 6 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'profi-2510.',
#   'chunk_text': 'model no: profi-2510. full description: isolated profibus repeater. short description: profibus repeater. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 15 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports profibus dp output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'profi-2541-sc.',
#   'chunk_text': 'model no: profi-2541-sc. full description: profibus dp to multi-mode fiber converter (sc-type). short description: profibus converter. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 15 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports fiber output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'gw-7552-b.',
#   'chunk_text': 'model no: gw-7552-b. full description: profibus to modbus gateway (plastic case). short description: profibus gateway. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'gw-7553-b.',
#   'chunk_text': 'model no: gw-7553-b. full description: profibus to modbus tcp gateway (plastic case). short description: profibus gateway. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 8 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'gw-7553-cpm.',
#   'chunk_text': 'model no: gw-7553-cpm. full description: profibus to canopen gateway (plastic case). short description: canopen gateway. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 slave devices. memory: not available. input protocol: supports profibus dp input protocol. output protocol: supports canopen output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7580.',
#   'chunk_text': 'model no: i-7580. full description: profinet to rs-232/422/485 converter. short description: profinet converter. serial port: supports rs232, rs485, and rs422 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 slave devices. memory: not available. input protocol: supports profinet input protocol. output protocol: supports rs232, rs485, and rs422 output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'gw-7662.',
#   'chunk_text': 'model no: gw-7662. full description: profinet to modbus rtu/ascii gateway. short description: profinet gateway. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 slave devices. memory: not available. input protocol: supports profinet input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'gw-7663.',
#   'chunk_text': 'model no: gw-7663. full description: profinet to modbus tcp gateway. short description: profinet gateway. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 8 slave devices. memory: not available. input protocol: supports profinet input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-2533cs.',
#   'chunk_text': 'model no: i-2533cs. full description: can to single-mode fiber bridge; 1 (30 km) single-mode, sc connector. short description: can converter. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 1 can device. memory: not available. input protocol: supports canbus input protocol. output protocol: supports fiber output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7531-fd-g.',
#   'chunk_text': 'model no: i-7531-fd-g. full description: two-channel isolated can / can fd signal repeater. short description: can repeater. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 2 can devices. memory: not available. input protocol: supports canbus input protocol. output protocol: supports canbus output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7530a-g.',
#   'chunk_text': 'model no: i-7530a-g. full description: intelligent rs-232/485/422 to can converter. short description: can converter. serial port: supports rs232, rs422, and rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 can devices. memory: not available. input protocol: supports canbus input protocol. output protocol: supports rs232, rs485, and rs422 output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7530a-mr-fd.',
#   'chunk_text': 'model no: i-7530a-mr-fd. full description: modbus rtu to can converter. short description: can gateway. serial port: supports rs232, rs422, and rs486 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 can devices. memory: not available. input protocol: supports canbus input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7540d-mtcp-g.',
#   'chunk_text': 'model no: i-7540d-mtcp-g. full description: can to ethernet / modbus tcp / modbus rtu converter (plastic case). short description: can gateway. serial port: supports rs232 and rs485 serial port. ethernet: supports modbus tcp and ip ethernet port. usb: no usb port available. channels: supports 8 can devices. memory: not available. input protocol: supports canbus input protocol. output protocol: supports modbus rtu and tcpip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7565-h2-g.',
#   'chunk_text': 'model no: i-7565-h2-g. full description: high performance intelligent usb to 2-port can bus converter (plastic case). short description: can bus gateway. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 2 s. memory: not available. input protocol: supports canbus input protocol. output protocol: supports usb output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'ecan-240-fd.',
#   'chunk_text': 'model no: ecan-240-fd. full description: modbus tcp to 2-port can fd gateway. short description: can bus gateway. serial port: not available. ethernet: supports modbus tcp and ip ethernet port. usb: no usb port available. channels: supports 2 s. memory: not available. input protocol: supports canbus input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'gw-7433d.',
#   'chunk_text': 'model no: gw-7433d. full description: modbus tcp server/rtu slave to canopen master gateway. short description: canopen gateway. serial port: supports rs232 and rs485 serial port. ethernet: supports modbus tcp and ip ethernet port. usb: no usb port available. channels: supports 8 can devices. memory: not available. input protocol: supports canopen input protocol. output protocol: supports modbus rtu and tcpip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'gw-2492m.',
#   'chunk_text': 'model no: gw-2492m. full description: bacnet/ip server to modbus rtu master gateway. short description: bacnet/ip gateway. serial port: supports rs232 and rs486 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 bacnet devices. memory: not available. input protocol: supports bacnet and ip input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'gw-2493m.',
#   'chunk_text': 'model no: gw-2493m. full description: bacnet/ip server to modbus tcp client gateway. short description: bacnet/ip gateway. serial port: not available. ethernet: supports modbus tcp and ip ethernet port. usb: no usb port available. channels: supports 8 bacnet devices. memory: not available. input protocol: supports bacnet and ip input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7590.',
#   'chunk_text': 'model no: i-7590. full description: rs-232/422/485 to m-bus converter. short description: m-bus converter. serial port: supports rs232, rs422, and rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 100 slave devices. memory: not available. input protocol: supports m-bus input protocol. output protocol: supports rs232, rs485, and rs422 output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'gw-7828.',
#   'chunk_text': 'model no: gw-7828. full description: modbus rtu slave to m-bus master gateway. short description: m-bus gateway. serial port: supports rs232, rs422, and rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 100 slave devices. memory: not available. input protocol: supports m-bus input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'gw-7838-m.',
#   'chunk_text': 'model no: gw-7838-m. full description: modbus tcp server to m-bus master gateway. short description: m-bus gateway. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 100 slave devices. memory: not available. input protocol: supports m-bus input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'dnp-211.',
#   'chunk_text': 'model no: dnp-211. full description: dnp3 master to modbus tcp server gateway. short description: dnp3 gateway. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 16 clients. memory: not available. input protocol: supports dnp3 input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'iec850-211-s.',
#   'chunk_text': 'model no: iec850-211-s. full description: modbus tcp to iec-61850 gateway. short description: iec-61850 gateway. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 561850 5 iec61850 clients. memory: not available. input protocol: supports iec61850 input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'm-7017-g.',
#   'chunk_text': 'model no: m-7017-g. full description: 8-ch ai module using dcon and modbus protocols (gray cover). short description: analog input module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: not available. input protocol: supports voltage and current input input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'm-7018-g.',
#   'chunk_text': 'model no: m-7018-g. full description: 8-ch thermocouple input module using dcon and modbus protocols (gray cover). short description: thermocouple input module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: not available. input protocol: supports thermocouple input input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'm-7019r-g.',
#   'chunk_text': 'model no: m-7019r-g. full description: 8-ch universal ai module with high voltage protection, using dcon and modbus protocols (gray cover). short description: analog input module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: not available. input protocol: supports thermocouple, cuurent, and voltage input input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'm-7015p-g.',
#   'chunk_text': 'model no: m-7015p-g. full description: 6-ch rtd input module with 3-wire lead resistance elimination using dcon and modbus protocols (gray cover). short description: rtd input module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 6 s. memory: not available. input protocol: supports rtd input input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7016d-g.',
#   'chunk_text': 'model no: i-7016d-g. full description: 2-ch 4-wire strain gauge input module with led display using dcon protocol (gray cover). short description: strain gauge input module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 2 s. memory: not available. input protocol: supports strain gauge input protocol. output protocol: supports dcon output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'm-7028d-g.',
#   'chunk_text': 'model no: m-7028d-g. full description: 8-ch 12-bit ao module with led display, using dcon and modbus protocols (gray cover). short description: analog output module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: not available. input protocol: supports voltage and current input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'm-7026-g.',
#   'chunk_text': 'model no: m-7026-g. full description: 6-ch ai, 2-ch ao, 3-ch di and 3-ch do module using dcon and modbus protocols (gray cover). short description: multifunction i/o module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: no channel information available. memory: not available. input protocol: supports analog and digital input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'm-7051d-g.',
#   'chunk_text': 'model no: m-7051d-g. full description: 16-ch isolated (dry, wet) di module with led display, using dcon and modbus protocols (gray cover). short description: digital input module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 16 s. memory: not available. input protocol: supports digital input input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'm-7045d-g.',
#   'chunk_text': 'model no: m-7045d-g. full description: 16-ch isolated (source, pnp, 10~40 vdc) do module with led display, using dcon and modbus protocols (gray cover). short description: digital output module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 16 s. memory: not available. input protocol: supports digital output input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'm-7055d-g.',
#   'chunk_text': 'model no: m-7055d-g. full description: 8-ch isolated (dry, wet) di and 8-ch isolated (source, pnp, 10~40 vdc) do module with led display, using dcon and modbus protocols (gray cover). short description: digital i/o module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 88 8 & 8s. memory: not available. input protocol: supports digital input & output input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'm-7061d-g.',
#   'chunk_text': 'model no: m-7061d-g. full description: 12-ch power relay module with led display, using dcon and modbus protocols (gray cover). short description: power relay module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 12 s. memory: not available. input protocol: supports 12 ch power relay input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'm-7069d-g.',
#   'chunk_text': 'model no: m-7069d-g. full description: 8-ch power relay (4x form a and 4x form c) module with led display, using dcon and modbus protocols (gray cover). short description: power relay module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: not available. input protocol: supports power relay (form a & form c) input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'tm-ad5.',
#   'chunk_text': 'model no: tm-ad5. full description: 5-channel isolation analog input module with high voltage protection. short description: analog input module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 5 s. memory: not available. input protocol: supports voltage input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'tm-ad5c.',
#   'chunk_text': 'model no: tm-ad5c. full description: 5-channel isolation current input module. short description: analog current input module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 5 s. memory: not available. input protocol: supports current input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'tm-p4c4.',
#   'chunk_text': 'model no: tm-p4c4. full description: 4-channel isolation di (wet) and 4-channel isolation do (sink, npn) module. short description: digital i/o module. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 44 4 & 4s. memory: not available. input protocol: supports digital input and output input protocol. output protocol: supports modbus rtu output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'tds-715.',
#   'chunk_text': 'model no: tds-715. full description: tiny (1x rs-422/485) serial-to-ethernet device server with poe (rohs) includes dc-jack to 2-wire power cable, 0. short description: serial device server. serial port: supports rs232, rs422, and rs485 serial port. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports rs232, rs422, and rs485 input protocol. output protocol: supports ethernet tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'ds-2235i.',
#   'chunk_text': 'model no: ds-2235i. full description: serial-to-ethernet device server with 2-port ethernet switch and 3-port isolated rs-422/485. short description: serial device server. serial port: supports rs422 and 485 serial port. ethernet: supports 2x tcp and ip ethernet port. usb: no usb port available. channels: supports 3 s. memory: not available. input protocol: supports rs422 and rs485 input protocol. output protocol: supports 2x ethernet tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'pds-755.',
#   'chunk_text': 'model no: pds-755. full description: programmable (1x rs-232 and 4x rs-485) serial-to-ethernet device server. short description: serial device server. serial port: supports rs232 and 485 serial port. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 14 1 & 4s. memory: not available. input protocol: supports rs232 and rs485 input protocol. output protocol: supports ethernet tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'msm-508.',
#   'chunk_text': 'model no: msm-508. full description: 8-port layer 2 managed switch with metal casing (rohs) includes ca-090510 console cable and 4six1k0000003 wall mount. short description: managed switch. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 8 s. memory: not available. input protocol: nan. output protocol: nan. cloud connectivity: no cloud connectivity. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'msm-508fcs-t.',
#   'chunk_text': 'model no: msm-508fcs-t. full description: 8-port industrial ethernet layer 2 managed switch with 2-fiber port (single-mode, sc connector). short description: managed switch with fiber. serial port: not available. ethernet: supports 8x ethernet ethernet port. usb: no usb port available. channels: supports 82 8 & 2s. memory: not available. input protocol: supports ethernet + fiber input protocol. output protocol: nan. cloud connectivity: no cloud connectivity. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'mdc-714.',
#   'chunk_text': 'model no: mdc-714. full description: modbus data concentrator with 1 x ethernet and 1 x rs-232, 4 x rs-485. short description: modbus data concentrator. serial port: supports rs232 and rs485 serial port. ethernet: supports modbus tcp and ip ethernet port. usb: no usb port available. channels: supports 14 1 & 4s. memory: not available. input protocol: supports rs232 and rs485 input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: no cloud connectivity. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'mdcl-705i.',
#   'chunk_text': 'model no: mdcl-705i. full description: modbus data concentrator with ethernet, rs-485 serial ports and data logger, includes one 32 gb microsd card. short description: modbus data concentrator. serial port: supports rs485 serial port. ethernet: supports modbus tcp and ip ethernet port. usb: no usb port available. channels: supports 5 s. memory: memory: 32gb. input protocol: supports modbus rtu input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: includes microsd slot. wi-fi: not supported'},
#  {'id': 'mdc-211-wf.',
#   'chunk_text': 'model no: mdc-211-wf. full description: wi-fi modbus data concentrator with 1 x ethernet, 1 x rs-232 and 1 x rs-485. short description: modbus data concentrator. serial port: supports rs232 and rs485 serial port. ethernet: supports modbus tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports modbus rtu and tcp ip input protocol. output protocol: supports wi-fi output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'ns-200afcs-t.',
#   'chunk_text': 'model no: ns-200afcs-t. full description: industrial 10/100 base-t to 100 base-fx media converter; 1 single mode, sc connector. short description: media converter. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports tcp and ip input protocol. output protocol: supports fiber output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7561u.',
#   'chunk_text': 'model no: i-7561u. full description: high-speed usb to isolated rs-232/422/485 converter with ca-usb18 cable. short description: usb to serial converter. serial port: supports rs232, 422, and 485 serial port. ethernet: not available. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports rs232, rs422, and rs485 input protocol. output protocol: supports usb output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7520a.',
#   'chunk_text': 'model no: i-7520a. full description: isolated rs-232 to rs-422/485 converter. short description: serial converter. serial port: supports rs232, 422, and 486 serial port. ethernet: not available. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports rs232 input protocol. output protocol: supports rs422 and 485 output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7551.',
#   'chunk_text': 'model no: i-7551. full description: isolated rs-232 to rs-232 repeater. short description: rs232 repeater. serial port: supports rs232 serial port. ethernet: not available. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports rs233 input protocol. output protocol: supports rs232 output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'i-7514u.',
#   'chunk_text': 'model no: i-7514u. full description: isolated 4-channel rs-485 repeater/hub/splitter. short description: rs485 hub. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 4 s. memory: not available. input protocol: supports rs485 input protocol. output protocol: nan. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'tsh-735.',
#   'chunk_text': 'model no: tsh-735. full description: tiny (3x rs-485) serial port sharer with poe (rohs) includes ca-002 cable. short description: sharer / splitter. serial port: supports rs485 serial port. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 3 s. memory: not available. input protocol: supports rs485 input protocol. output protocol: nan. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'usb',
#   'chunk_text': 'model no: usb 2514. full description: usb to 4-port rs-232 converter. short description: usb to rs232 converter. serial port: supports rs232 serial port. ethernet: not available. usb: no usb port available. channels: supports 4 s. memory: not available. input protocol: supports rs232 input protocol. output protocol: supports usb output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'tgw-718.',
#   'chunk_text': 'model no: tgw-718. full description: tiny modbus tcp to rtu/ascii gateway with poe and 1-port rs-232/422/485. short description: modbus gateway. serial port: supports rs232, 422, and 486 serial port. ethernet: supports modbus tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports modbus rtu input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'zt-2017.',
#   'chunk_text': 'model no: zt-2017. full description: zigbee wireless 8-ch analog input module with high voltage protection (zigbee router). short description: analog input module with zigbee. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: not available. input protocol: supports voltage & current input protocol. output protocol: supports zigbee output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'zt-2055.',
#   'chunk_text': 'model no: zt-2055. full description: zigbee wireless 8-ch isolated di and 8-ch isolated do module (zigbee router). short description: zigbee digital i/o module. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: not available. input protocol: supports digital i and o module input protocol. output protocol: supports zigbee output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'zt-2026.',
#   'chunk_text': 'model no: zt-2026. full description: zigbee wireless 4-ch voltage input, 2-ch voltage output, 2-ch di and 2-ch do module (zigbee router). short description: zigbee multifunction module. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 2 s. memory: not available. input protocol: supports voltage & digital input and output input protocol. output protocol: supports zigbee output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'zt-2570.',
#   'chunk_text': 'model no: zt-2570. full description: ethernet/rs-232/rs-485 to zigbee converter (zigbee coordinator). short description: zigbee converter. serial port: supports rs232, rs485, and serial port. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports rs232 and rs485 input protocol. output protocol: supports zigbee output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'pmc-5231m-4ge.',
#   'chunk_text': 'model no: pmc-5231m-4ge. full description: industrial iot power meter concentrator (support 4g communication. short description: power concentrator module. serial port: supports rs232 and 485 serial port. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 16 s. memory: memory: 32gb. input protocol: supports modbus tcp and rtu input protocol. output protocol: supports snmp & snmp trap, mqtt, and ddns output protocol. cloud connectivity: cloud connectivity available. sim card: supports a single 4g sim card. micro sd: includes 32gb microsd card. wi-fi: not supported'},
#  {'id': 'wise-5231m-4ge.',
#   'chunk_text': 'model no: wise-5231m-4ge. full description: iiot edge controller (metal case) (support 4g communication. short description: iot gateway. serial port: supports rs232 and 486 serial port. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 16 s. memory: memory: 32gb. input protocol: supports modbus tcp and rtu input protocol. output protocol: supports snmp & snmp trap, ftp, mqtt, and cgi command ddns output protocol. cloud connectivity: cloud connectivity available. sim card: supports a single 4g sim card. micro sd: includes 32gb microsd card. wi-fi: not supported'},
#  {'id': 'sg-3071.',
#   'chunk_text': 'model no: sg-3071. full description: dc voltage input signal conditioner. short description: signal conditiner module. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports 0-5vdc and 0-10vdc input protocol. output protocol: supports 0-5vdc, 0-10vdc or 0-20ma, and 4-20ma output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'sg-3081-g.',
#   'chunk_text': 'model no: sg-3081-g. full description: dc current input signal conditioner. short description: signal conditiner module. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports 0-20ma and 4-20ma input protocol. output protocol: supports 0-5vdc, 0-10vdc or 0-20ma, and 4-20ma output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'et-7017.',
#   'chunk_text': 'model no: et-7017. full description: ethernet i/o module with 8-ch ai, 4-ch do. short description: analog input to modbus tcp/ip. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports analog input (150mv, 500mv, 1v, 5v, 10v, 20ma, 0-20ma, and 4-20ma input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'et-7026.',
#   'chunk_text': 'model no: et-7026. full description: ethernet i/o module with 6-ch ai, 2-ch ao, 2-ch di, 2-ch do. short description: multifunction input to modbus tcp/ip. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports analog input 500mv, 1v, 5v, 10v, 20ma, 0-20ma, 4-20ma, digigital i, and o input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'et-7051.',
#   'chunk_text': 'model no: et-7051. full description: ethernet i/o module with 16-ch di. short description: digital input to modbus tcp/ip. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports digital input input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'et-7052.',
#   'chunk_text': 'model no: et-7052. full description: ethernet i/o module with 8-ch di, 8-ch do. short description: digital i/o to modbus tcp/ip. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports digital input & output input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'et-7042.',
#   'chunk_text': 'model no: et-7042. full description: ethernet i/o module with 16-ch do. short description: digital output to modbus tcp/ip. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports digital output input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'dl-10.',
#   'chunk_text': 'model no: dl-10. full description: remote temperature/humidity/dew point sensing module, using modbus rtu protocol, 3 m (white cover). short description: tempreture and humidity to modbus rtu. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports tempreture & humidity input protocol. output protocol: supports modbus tcp and ip output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'dl-100s-e-w.',
#   'chunk_text': 'model no: dl-100s-e-w. full description: ip66 remote temperature and humidity data logger with lcd display, using modbus tcp and mqtt protocols. short description: tempreture and humidity data logger with mqtt protocol and tcp/ip. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports tempreture & humidity input protocol. output protocol: supports modbus tcp and ip & mqtt output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'dl-1023.',
#   'chunk_text': 'model no: dl-1023. full description: remote pm1/2. short description: industrial gases data logger. serial port: supports rs485 serial port. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports tempreture & humidity pm1, 2. output protocol: supports modbus rtu & tcp and ip & mqtt output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'r2010-4l.',
#   'chunk_text': 'model no: r2010-4l. full description: industrial cellular gateway 2 eth+1rs232/rs485+ 1 di + 1do. short description: industrial cellular gateway. serial port: supports rs232 and 485 serial port. ethernet: supports 2 x ethernet ethernet port. usb: no usb port available. channels: no channel information available. memory: memory: 16mb. input protocol: supports modbus rtu and tcp input protocol. output protocol: supports ipsec, mqtt, dnp3, iec104, and l2tp output protocol. cloud connectivity: cloud connectivity available. sim card: supports dual 4g sim cards. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'r3000-l4l.',
#   'chunk_text': 'model no: r3000-l4l. full description: industrial dual sim cellular vpn router 1 eth + 1 rs-232 + 1 rs-485 + 1 usb host. short description: dual sim cellular vpn router. serial port: supports rs232 and 485 serial port. ethernet: supports 1 x ethernet ethernet port. usb: no usb port available. channels: supports 8 s. memory: memory: 16mb. input protocol: supports modbus rtu and tcp input protocol. output protocol: supports ipsec, mqtt, dnp3, iec104, and l2tp output protocol. cloud connectivity: cloud connectivity available. sim card: supports dual 4g sim cards. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'r5020-lite.',
#   'chunk_text': 'model no: r5020-lite. full description: high speed smart 5g router 2 eth + 1 rs232 /rs485 + high-speed dual-band wi-fi. short description: industrial 5g router. serial port: supports rs232 and 485 serial port. ethernet: supports 2 x ethernet ethernet port. usb: no usb port available. channels: supports 8 s. memory: memory: 16mb. input protocol: supports modbus rtu and tcp input protocol. output protocol: supports ipsec, mqtt, dnp3, iec104, and l2tp output protocol. cloud connectivity: cloud connectivity available. sim card: supports dual 5g sim cards. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'nt-rtu-23.',
#   'chunk_text': 'model no: nt-rtu-23. full description: industrial cellular modem 2 eth+ 1 rs232/rs485 + 1 di + 1 do. short description: vpn router. serial port: supports rs232 and 485 serial port. ethernet: supports 2 x ethernet ethernet port. usb: no usb port available. channels: supports 10 s. memory: memory: 16mb. input protocol: supports modbus rtu and tcp input protocol. output protocol: supports ipsec, mqtt, dnp3, iec104, and l2tp output protocol. cloud connectivity: cloud connectivity available. sim card: supports dual 4g sim cards. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'nt-rtu-24.',
#   'chunk_text': 'model no: nt-rtu-24. full description: embedded 4g router 2 ethernet + wi-fi + 1 sim + 1 rs232/rs485. short description: industreial 4g router. serial port: supports rs232 and 486 serial port. ethernet: supports 2 x ethernet ethernet port. usb: no usb port available. channels: supports 10 s. memory: memory: 16mb. input protocol: supports modbus rtu and tcp input protocol. output protocol: supports ipsec, mqtt, dnp3, iec104, and l2tp output protocol. cloud connectivity: cloud connectivity available. sim card: supports a single 4g sim card. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'nt-201-s-u.',
#   'chunk_text': 'model no: nt-201-s-u. full description: lora to rs232/422/485 converter. short description: lora to serial converter. serial port: supports rs232 and 487 serial port. ethernet: not available. usb: no usb port available. channels: supports 10 s. memory: memory: 16kb. input protocol: supports modbus rtu input protocol. output protocol: supports lora output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'nt-201-dio-u.',
#   'chunk_text': 'model no: nt-201-dio-u. full description: lora to 4 digital input & 3 digital output module. short description: lora digital i/o module. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: memory: 128kb. input protocol: supports digital input & output input protocol. output protocol: supports lora output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'nts-201-ai.',
#   'chunk_text': 'model no: nts-201-ai. full description: analog input to lorawan converter. short description: lorawan converter. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: memory: 16kb. input protocol: supports analog input(0-10vdc and 4-20ma) input protocol. output protocol: supports lorawan output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'nts-201-ao.',
#   'chunk_text': 'model no: nts-201-ao. full description: analog output to lora converter. short description: lorawan converter. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: memory: 380kb. input protocol: supports analog output input protocol. output protocol: supports lorawan output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'nts-201-dio.',
#   'chunk_text': 'model no: nts-201-dio. full description: 2 di & 2 do to lorawan module. short description: lorawan converter. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 8 s. memory: memory: 380kb. input protocol: supports digital input & output input protocol. output protocol: supports lorawan output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'nt-201-e-modbus.',
#   'chunk_text': 'model no: nt-201-e-modbus. full description: modbus ethernet to lora converter. short description: lora converter. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 8 s. memory: memory: 128kb. input protocol: supports modbus tcp and ip input protocol. output protocol: supports lora output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'usb232.',
#   'chunk_text': 'model no: usb232. full description: rs232 to usb onverter. short description: rs232 converter. serial port: supports rs232 serial port. ethernet: not available. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports rs232 input protocol. output protocol: supports usb output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'usb485.',
#   'chunk_text': 'model no: usb485. full description: rs485 to usb onverter. short description: rs485 converter. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports rs485 input protocol. output protocol: supports usb output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'nt-832-ah-e.',
#   'chunk_text': 'model no: nt-832-ah-e. full description: ethernet to wi-fi converter. short description: wi-fi converter. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports tcp and ip input protocol. output protocol: supports wi-fi output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'nt-832-ah-485.',
#   'chunk_text': 'model no: nt-832-ah-485. full description: rs485 to wi-fi. short description: wi-fi converter. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports rs485 input protocol. output protocol: supports wi-fi output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'nt-201-g-wan',
#   'chunk_text': 'model no: nt-201-g-wan+4g. full description: ethernet to lorawan gateway. short description: lorawan gateway. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 8 s. memory: memory: 32 mb. input protocol: supports tcp and ip input protocol. output protocol: supports udp, mqtt, dhcp, and static ip and dhcp server output protocol. cloud connectivity: cloud connectivity available. sim card: supports a single 4g sim card. micro sd: includes microsd slot. wi-fi: not supported'},
#  {'id': 'nt-632-pi-cm4.',
#   'chunk_text': 'model no: nt-632-pi-cm4. full description: programmable gateway. short description: risbery pi gateway. serial port: supports rs232, 485, and 422 serial port. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: memory: 8/16/32gb. input protocol: supports modbus rtu and tcp input protocol. output protocol: supports mqtt output protocol. cloud connectivity: cloud connectivity available. sim card: supports a single 4g sim card. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'tns-200in.',
#   'chunk_text': 'model no: tns-200in. full description: 10/100 base-tx, poe injector for 1 poe port. short description: poe splitter. serial port: not available. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports tcp and ip input protocol. output protocol: supports poe output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'nt-4421.',
#   'chunk_text': 'model no: nt-4421. full description: 4di, 2do, 4ai, with rs485. short description: iot gateway. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 1. memory: not available. input protocol: supports modbus rtu input protocol. output protocol: supports mqtt output protocol. cloud connectivity: cloud connectivity available. sim card: supports a single 4g sim card. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'nt-s1-4g.',
#   'chunk_text': 'model no: nt-s1-4g. full description: rs485 to server. short description: 4g iot gateway. serial port: supports rs485 serial port. ethernet: not available. usb: no usb port available. channels: supports 6 s. memory: not available. input protocol: supports modbus rtu input protocol. output protocol: supports mqtt output protocol. cloud connectivity: cloud connectivity available. sim card: supports a single 4g sim card. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'nt-t20-4g.',
#   'chunk_text': 'model no: nt-t20-4g. full description: tempreture and humidity data logger. short description: tempreture data logger. serial port: not available. ethernet: not available. usb: no usb port available. channels: supports 1. memory: memory: yes. input protocol: supports tempreture & humidity input protocol. output protocol: supports mqtt output protocol. cloud connectivity: cloud connectivity available. sim card: supports a single 4g sim card. micro sd: not supported. wi-fi: not supported'},
#  {'id': 'nt-mb307b.',
#   'chunk_text': 'model no: nt-mb307b. full description: analog and digital i/o to modbus rtu or tcp/ip converter. short description: multifunction i/o to modbus rtu/tcp converter. serial port: supports rs485 and 232 serial port. ethernet: supports tcp and ip ethernet port. usb: no usb port available. channels: supports 8 s. memory: not available. input protocol: supports analog and digital i and o module input protocol. output protocol: supports modbus rtu and tcp output protocol. cloud connectivity: cloud connectivity via external modem. sim card: not supported. micro sd: not supported. wi-fi: not supported'}]

# %%
index = pc.Index("model-prompter")
index.insert(records=formatted_docs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 index = pc.Index("model-prompter")
# ----> 2 index.insert(records=formatted_docs)
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/utils/plugin_aware.py:106, in PluginAware.__getattr__(self, name)
#     102     except AttributeError:
#     103         # If we can't get the required attributes, we can't load plugins
#     104         pass
# --> 106 raise AttributeError(f"'{self.__class__.__name__}' object has no attribute '{name}'")
#
# AttributeError: 'Index' object has no attribute 'insert'

# %%
# docs = [item["embedding_text"] for item in products]
# embeddings = get_embeddings(docs)

# %%
vectors = []

for i, item in enumerate(products):
    vectors.append({
        "id": item["model_no"],  # unique ID per model
        "values": embeddings[i],  # corresponding embedding
        "metadata": {
           
            "full_description": item["full_description"],
            "embedding_text": item["embedding_text"]
        }
    })

# Upload in batches (for large uploads)
index.upsert(vectors=vectors)
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[14], line 15
#      14 # Upload in batches (for large uploads)
# ---> 15 index.upsert(vectors=vectors)
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/utils/error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/utils/error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/db_data/index.py:212, in Index.upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     211 if batch_size is None:
# --> 212     return self._upsert_batch(vectors, namespace, _check_type, **kwargs)
#     214 if not isinstance(batch_size, int) or batch_size <= 0:
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/db_data/index.py:238, in Index._upsert_batch(self, vectors, namespace, _check_type, **kwargs)
#     229 def _upsert_batch(
#     230     self,
#     231     vectors: Union[
#    (...)    236     **kwargs,
#     237 ) -> UpsertResponse:
# --> 238     return self._vector_api.upsert_vectors(
#     239         IndexRequestFactory.upsert_request(vectors, namespace, _check_type, **kwargs),
#     240         **self._openapi_kwargs(kwargs),
#     241     )
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/core/openapi/db_data/api/vector_operations_api.py:675, in VectorOperationsApi.__init__.<locals>.__upsert_vectors(self, upsert_request, **kwargs)
#     674 kwargs["upsert_request"] = upsert_request
# --> 675 return self.call_with_http_info(**kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Tue, 15 Jul 2025 11:48:56 GMT', 'Content-Type': 'application/json', 'Content-Length': '104', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '3743', 'x-pinecone-request-id': '5524559877245460507', 'x-envoy-upstream-service-time': '51', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 1536 does not match the dimension of the index 2048","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[14], line 15
#      14 # Upload in batches (for large uploads)
# ---> 15 index.upsert(vectors=vectors)
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/utils/error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/utils/error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/db_data/index.py:212, in Index.upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     211 if batch_size is None:
# --> 212     return self._upsert_batch(vectors, namespace, _check_type, **kwargs)
#     214 if not isinstance(batch_size, int) or batch_size <= 0:
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/db_data/index.py:238, in Index._upsert_batch(self, vectors, namespace, _check_type, **kwargs)
#     229 def _upsert_batch(
#     230     self,
#     231     vectors: Union[
#    (...)    236     **kwargs,
#     237 ) -> UpsertResponse:
# --> 238     return self._vector_api.upsert_vectors(
#     239         IndexRequestFactory.upsert_request(vectors, namespace, _check_type, **kwargs),
#     240         **self._openapi_kwargs(kwargs),
#     241     )
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/core/openapi/db_data/api/vector_operations_api.py:675, in VectorOperationsApi.__init__.<locals>.__upsert_vectors(self, upsert_request, **kwargs)
#     674 kwargs["upsert_request"] = upsert_request
# --> 675 return self.call_with_http_info(**kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Tue, 15 Jul 2025 11:48:56 GMT', 'Content-Type': 'application/json', 'Content-Length': '104', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '3743', 'x-pinecone-request-id': '5524559877245460507', 'x-envoy-upstream-service-time': '51', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 1536 does not match the dimension of the index 2048","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
# Cell In[14], line 15
#       4     vectors.append({
#       5         "id": item["model_no"],  # unique ID per model
#       6         "values": embeddings[i],  # corresponding embedding
#    (...)     11         }
#      12     })
#      14 # Upload in batches (for large uploads)
# ---> 15 index.upsert(vectors=vectors)
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/utils/error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      26     raise ProtocolError(
#      27         "Connection failed. Please verify that the index host is correct and accessible."
#      28     ) from e
#      29 else:
# ---> 30     raise e from e
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/utils/error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      12 @wraps(func)
#      13 def inner_func(*args, **kwargs):
#      14     try:
# ---> 15         return func(*args, **kwargs)
#      16     except Exception as e:
#      17         # Lazy import of urllib3 exceptions
#      18         from urllib3.exceptions import MaxRetryError, ProtocolError as Urllib3ProtocolError
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/db_data/index.py:212, in Index.upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     205     raise ValueError(
#     206         "async_req is not supported when batch_size is provided."
#     207         "To upsert in parallel, please follow: "
#     208         "https://docs.pinecone.io/docs/insert-data#sending-upserts-in-parallel"
#     209     )
#     211 if batch_size is None:
# --> 212     return self._upsert_batch(vectors, namespace, _check_type, **kwargs)
#     214 if not isinstance(batch_size, int) or batch_size <= 0:
#     215     raise ValueError("batch_size must be a positive integer")
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/db_data/index.py:238, in Index._upsert_batch(self, vectors, namespace, _check_type, **kwargs)
#     229 def _upsert_batch(
#     230     self,
#     231     vectors: Union[
#    (...)    236     **kwargs,
#     237 ) -> UpsertResponse:
# --> 238     return self._vector_api.upsert_vectors(
#     239         IndexRequestFactory.upsert_request(vectors, namespace, _check_type, **kwargs),
#     240         **self._openapi_kwargs(kwargs),
#     241     )
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/core/openapi/db_data/api/vector_operations_api.py:675, in VectorOperationsApi.__init__.<locals>.__upsert_vectors(self, upsert_request, **kwargs)
#     673 kwargs = self._process_openapi_kwargs(kwargs)
#     674 kwargs["upsert_request"] = upsert_request
# --> 675 return self.call_with_http_info(**kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     285     return self.threadpool_executor.submit(
#     286         self.__call_api,
#     287         resource_path,
#    (...)    302         _check_type,
#     303     )
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#     186 return_data = response_data
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     161 url = build_request_url(
#     162     config=config,
#     163     processed_path_params=path_params_tuple,
#     164     resource_path=resource_path,
#     165     _host=_host,
#     166 )
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     376     return self.rest_client.OPTIONS(
#     377         url,
#     378         query_params=query_params,
#    (...)    383         body=body,
#     384     )
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#     396     return self.rest_client.PUT(
#     397         url,
#     398         query_params=query_params,
#    (...)    403         body=body,
#     404     )
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     264     # log response body
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File ~/miniconda3/lib/python3.13/site-packages/pinecone/openapi_support/rest_utils.py:49, in raise_exceptions_or_return(r)
#      46     if 500 <= r.status <= 599:
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Tue, 15 Jul 2025 11:48:56 GMT', 'Content-Type': 'application/json', 'Content-Length': '104', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '3743', 'x-pinecone-request-id': '5524559877245460507', 'x-envoy-upstream-service-time': '51', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 1536 does not match the dimension of the index 2048","details":[]}
